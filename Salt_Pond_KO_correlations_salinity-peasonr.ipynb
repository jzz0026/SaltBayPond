# %% [markdown]
# # Salt Pond KO correlations with Env
# ###### modified from Salinity Gradient: SF_ Sal MG working with Heat, Scatter, subsets: Env, Ontol
# ###### New Ontology INTEGRATION version

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
from scipy.stats import norm
from scipy.stats import skew
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
# import fastcluster
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib import ticker

# %% [markdown]
# ## Gather input data

# %% [markdown]
# ### Environment data

# %%
# Import and clean environment data
# IMPROVED LOG DATA
Sal_meta = pd.read_csv('Salt_Pond_metaLOG_FIX.txt', sep='\t', index_col=0)

Sal_meta.loc[:,['CH4_umol_m2_d','CH4_m2_lin']]
# Sal_meta.head(10)
# Out:
#     CH4_umol_m2_d  CH4_m2_lin
# 0             NaN      -24.30
# 1             NaN      -24.30
# 2             NaN       -1.76
# 3             NaN       -1.76
# 4             NaN       -7.10
# 5             NaN       -7.10
# 6        0.646404        4.43
# 7        0.646404        4.43
# 8        1.617525       41.45
# 9        1.617525       41.45
# 10       1.021189       10.50
# 11       1.021189       10.50
# 12       2.867656      737.32
# 13       2.867656      737.32
# 14       3.129410     1347.13
# 15       3.129410     1347.13
# 16       2.690612      490.47
# 17       2.690612      490.47
# 18       3.122930     1327.18
# 19       3.122930     1327.18
# 20       3.206040     1607.09
# 21       3.206040     1607.09
# 22       3.201006     1588.57
# 23       3.201006     1588.57

# %%
# OLD LINEAR DATA 
# Sal_meta = pd.read_csv('SF_sal_meta_FIX.txt', sep='\t', index_col=1)
# Sal_meta['logCH4'] = np.log10(Sal_meta['CH4_ug_m2_h'])  
# Sal_metaS = Sal_meta.sort_values(by='Site_indx') #, inplace=True)
# Sal_meta.columns # Sal_meta.head(10)

# %% [markdown]
# ### @@@@@@@@@@@@@@@@@@@@@@@
# ## Subset environment

# %% [markdown]
# ### Make Environment Subsets

# %%
### DEPTH
Depth1_ONLY = Sal_meta[Sal_meta['Depth'].str.contains('D1')]
Depth2_ONLY = Sal_meta[Sal_meta['Depth'].str.contains('D2')]

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# # Environment SUBSET Selector

# %%
#   [[[ ON / OFF ]]]            # by commenting out -- NOTE Sequence will matter if [[[ ON ]]]

# Sal_meta = Depth1_ONLY        # Depth 1
# Sal_meta = Depth1_ONLY        # Depth 2

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %% [markdown]
# ### @@@@@@@@@@@@@@@@@@@@@@@
# ### Env. Chem variable selector

# %%
## CUT Down Env. Data
env_chem_List = ['Salinity','Cond_uS_cm', 'Temp', 'DO_perc', 'DO_mg_L', 'Redox', 'pH_YSI',
    'CH4_umol_m2_d', 'CO2_umol_m2_d', 'CH4_CO2', 'CH4_pos', 'CH4_CO2_pos',
    'pH', 'Cl', 'SO4_S', 'TOC', 'OM_LOI', 'C_Org_LOI', 'CaCO3', 'C', 'N','P', 
    'CN', 'CP', 'NP', 'NO3', 'NH4', 'Olsen_P', 'NP_ext', 'NO3_NH4', 
    'K_ppm', 'K_meq', 'Na_ppm', 'Na_meq', 'Ca', 'Mg', 'Zn', 'Mn', 'Cu',
    'Fe', 'CH4_m2_lin', 'CO2_m2_lin', 'Salinity_lin', 'pH_lin'] 
    
        # with log DATA, delete 'logCH4' now is logged, except for LIN vars
        # Drop cations, corr w. Sal: 'Ca_pw', 'Sr_pw','Mg_pw', 'Na_pw', 'K_pw', 'Al_pw', 'Si_pw', 'Br_pw', 'F_pw', 'logCH4']
        # Drop soil metals for now, half NA: 'Fe', 'Mn', 'Cu', 'Zn']
        # Drop redundant cols for PW: 'Salinity.x.1', 'CO2_mg_m2_h.1','CH4_ug_m2_h.1'

# ABSTRACT Env_chem
Env_chem = Sal_meta[env_chem_List]  # Get columns
Env_chem.head()

# Env_chem.fillna(0, inplace = True)  # Fill NAs w 0, for porewater ND - careful with soil metals

## ReINDEX Env. chem, MUST BE by Sample
Sample= Sal_meta['Sample'] 
Env_chem = Env_chem.set_index(Sample,0) 
del Env_chem.index.name        

#Sal_meta[["Sample_name","CH4_m2_lin"]]
# Env_chem.head()
# Env_chem.head(24)
Sal_meta
# Out:
#     New_index         Sample_name    Sample  Site Core Depth Restoration  \
# 0           1   Historic_R2A_A_D1  R2A_A_D1  R2A     A    D1    Historic
# 1           2   Historic_R2A_A_D2  R2A_A_D2  R2A     A    D2    Historic
# 2           3   Historic_R2A_B_D1  R2A_B_D1  R2A     B    D1    Historic
# 3           4   Historic_R2A_B_D2  R2A_B_D2  R2A     B    D2    Historic
# 4           5   Historic_R2A_C_D1  R2A_C_D1  R2A     C    D1    Historic
# 5           6   Historic_R2A_C_D2  R2A_C_D2  R2A     C    D2    Historic
# 6           7   restored_SF2_A_D1  SF2_A_D1   SF2    A    D1    Restored
# 7           8   restored_SF2_A_D2  SF2_A_D2   SF2    A    D2    Restored
# 8           9   restored_SF2_B_D1  SF2_B_D1   SF2    B    D1    Restored
# 9          10   restored_SF2_B_D2  SF2_B_D2   SF2    B    D2    Restored
# 10         11   restored_SF2_C_D1  SF2_C_D1   SF2    C    D1    Restored
# 11         12   restored_SF2_C_D2  SF2_C_D2   SF2    C    D2    Restored
# 12         13  unrestored_R1_A_D1   R1_A_D1    R1    A    D1   Salt_Pond
# 13         14  unrestored_R1_A_D2   R1_A_D2    R1    A    D2   Salt_Pond
# 14         15  unrestored_R1_B_D1   R1_B_D1    R1    B    D1   Salt_Pond
# 15         16  unrestored_R1_B_D2   R1_B_D2    R1    B    D2   Salt_Pond
# 16         17  unrestored_R1_C_D1   R1_C_D1    R1    C    D1   Salt_Pond
# 17         18  unrestored_R1_C_D2   R1_C_D2    R1    C    D2   Salt_Pond
# 18         19  unrestored_R2_A_D1   R2_A_D1    R2    A    D1   Salt_Pond
# 19         20  unrestored_R2_A_D2   R2_A_D2    R2    A    D2   Salt_Pond
# 20         21  unrestored_R2_B_D1   R2_B_D1    R2    B    D1   Salt_Pond
# 21         22  unrestored_R2_B_D2   R2_B_D2    R2    B    D2   Salt_Pond
# 22         23  unrestored_R2_C_D1   R2_C_D1    R2    C    D1   Salt_Pond
# 23         24  unrestored_R2_C_D2   R2_C_D2    R2    C    D2   Salt_Pond
#
#           Hydrol     Date        Lat   ...          Mn        Cu        Fe  \
# 0    Tidal marsh  7/11/14  37.496219   ...    2.019532  0.342423  2.471878
# 1    Tidal marsh  7/11/14  37.496219   ...    1.322219  0.518514  2.565376
# 2    Tidal marsh  7/11/14  37.496044   ...    2.065206  0.361728  2.430559
# 3    Tidal marsh  7/11/14  37.496044   ...    1.663701  0.278754  2.604226
# 4    Tidal marsh  7/11/14  37.496546   ...    2.599337  0.477121  1.997386
# 5    Tidal marsh  7/11/14  37.496546   ...    1.505150  0.579784  2.646502
# 6   Managed pond  7/17/14  37.497143   ...    1.635484  0.690196  2.503518
# 7   Managed pond  7/17/14  37.497143   ...    1.380211  0.146128  2.596707
# 8   Managed pond  7/17/14  37.497202   ...    1.418301  0.778151  2.479575
# 9   Managed pond  7/17/14  37.497202   ...    1.155336  0.740363  2.275311
# 10  Managed pond  7/17/14  37.497356   ...    1.247973  0.079181  2.572174
# 11  Managed pond  7/17/14  37.497356   ...    1.029384  0.707570  2.432488
# 12          Pond  7/11/14  37.496912   ...    2.035029  0.397940  2.018284
# 13          Pond  7/11/14  37.496912   ...    1.932474  0.431364  2.105851
# 14         Pond   7/11/14  37.496812   ...    2.198382  0.322219  1.955688
# 15         Pond   7/11/14  37.496812   ...    2.242790  0.397940  1.840106
# 16          Pond  7/11/14  37.497168   ...    2.225568  0.204120  1.890980
# 17          Pond  7/11/14  37.497168   ...    1.838849  0.477121  2.135769
# 18          Pond  7/11/14  37.495828   ...    1.509203 -0.301030  1.594393
# 19          Pond  7/11/14  37.495828   ...    1.606381  0.176091  2.260548
# 20          Pond  7/11/14  37.496143   ...    1.712650  0.278754  2.031004
# 21          Pond  7/11/14  37.496143   ...    1.843233  0.255273  2.163758
# 22          Pond  7/11/14  37.496500   ...    1.558709  0.278754  2.101403
# 23          Pond  7/11/14  37.496500   ...    1.723456  0.414973  2.150756
#
#     CH4_m2_lin  CO2_m2_lin  Salinity_lin  pH_lin    NP_ext_lin     NP_lin  \
# 0       -24.30   300262.17          36.0    6.37    322.112865   8.484259
# 1       -24.30   300262.17          36.0    6.19    127.168786   9.174638
# 2        -1.76   187121.85          46.5    6.41    227.949095  10.548608
# 3        -1.76   187121.85          46.5    6.18    309.915042  16.091627
# 4        -7.10   266086.03          39.3    6.17    332.871712  11.275017
# 5        -7.10   266086.03          39.3    5.86    124.276709  10.513483
# 6         4.43    83774.43          29.1    7.32    875.341155   7.008769
# 7         4.43    83774.43          29.1    6.95    947.754718   5.696967
# 8        41.45   145215.88          33.3    7.24   1606.204207  11.005188
# 9        41.45   145215.88          33.3    7.21   2394.216685   8.992713
# 10       10.50  -237242.07          36.4    7.07    462.996565   6.596489
# 11       10.50  -237242.07          36.4    6.91   1582.102739   8.394001
# 12      737.32   445576.11          97.2    7.41  13534.869911  15.479260
# 13      737.32   445576.11          97.2    7.56  21735.900602  14.025240
# 14     1347.13   347733.05         147.6    7.63  12484.394191  12.187405
# 15     1347.13   347733.05         147.6    7.23  15361.530329  11.420503
# 16      490.47   213509.81         147.3    7.48  10027.677812  13.325374
# 17      490.47   213509.81         147.3    7.27   9652.131823  20.245890
# 18     1327.18   405266.90         231.1    7.23   3446.698008  16.806054
# 19     1327.18   405266.90         231.1    6.78   7924.179772  19.191124
# 20     1607.09   407399.78         166.8    6.83   2798.860073  18.940461
# 21     1607.09   407399.78         166.8    6.79   6933.242236  21.165519
# 22     1588.57   520659.80         232.4    6.72   7316.618622  16.953476
# 23     1588.57   520659.80         232.4    6.77   4842.848246  17.350380
#
#     Cl_lin
# 0      541
# 1      518
# 2      563
# 3      509
# 4      536
# 5      527
# 6      604
# 7      604
# 8      803
# 9      920
# 10     618
# 11     712
# 12    4206
# 13    3019
# 14    3014
# 15    4228
# 16    3484
# 17    4043
# 18    4655
# 19    4495
# 20    4499
# 21    4546
# 22    4727
# 23    4582
#
# [24 rows x 58 columns]

# %% [markdown]
# # Plot env data for electron acceptor testing

# %%
Sal_env_rm = Sal_meta.iloc[:,11:]
Sal_env_coronly = Sal_env_rm.corr()
cm=sns.clustermap(Sal_env_coronly, vmax=0.8, row_cluster=True, col_cluster=True, 
             square=False, figsize = (10,10));          # , figsize = (10,20))         
plt.setp(cm.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)   # rotate ticks
plt.show()

# %%
Sal_meta.columns
# Out:
# Index([u'New_index', u'Sample_name', u'Sample', u'Site', u'Core', u'Depth',
#        u'Restoration', u'Hydrol', u'Date', u'Lat', u'Long', u'Salinity',
#        u'Cond_uS_cm', u'Temp', u'DO_perc', u'DO_mg_L', u'Redox', u'pH_YSI',
#        u'CH4_umol_m2_d', u'CO2_umol_m2_d', u'CH4_CO2', u'CH4_pos',
#        u'CH4_CO2_pos', u'pH', u'Cl', u'SO4_S', u'TOC', u'OM_LOI', u'C_Org_LOI',
#        u'CaCO3', u'C', u'N', u'P', u'CN', u'CP', u'NP', u'NO3', u'NH4',
#        u'Olsen_P', u'NP_ext', u'NO3_NH4', u'K_ppm', u'K_meq', u'Na_ppm',
#        u'Na_meq', u'Ca', u'Mg', u'Zn', u'Mn', u'Cu', u'Fe', u'CH4_m2_lin',
#        u'CO2_m2_lin', u'Salinity_lin', u'pH_lin', u'NP_ext_lin', u'NP_lin',
#        u'Cl_lin'],
#       dtype='object')

# %%
#sns.boxplot(x="Restoration", y="CH4_m2_lin", data=Sal_meta, palette="PRGn")
#sns.boxplot(x="Restoration", y="Salinity", data=Sal_meta, palette="PRGn")

#sns.boxplot(x="Restoration", y="SO4_S", data=Sal_meta, palette="PRGn")
#sns.boxplot(x="Restoration", y="NO3", data=Sal_meta, palette="PRGn")
#sns.boxplot(x="Restoration", y="DO_mg_L", data=Sal_meta, palette="PRGn")
#sns.boxplot(x="Restoration", y="pH_lin", data=Sal_meta, palette="PRGn")
a_list =["SO4_S","NO3","DO_mg_L","pH_lin"]
def concat_columns(a_list):
    frames = [ Sal_meta[["Restoration",each]] for each in a_list ]
    for a in frames:
        a["type"] = a.columns[1]
        a.columns = ["Restoration","values","type"] 

    return pd.concat(frames)
df_CH4sal = concat_columns(a_list)
df_CH4sal
sns.factorplot(x="Restoration", y="values", hue="type",data=df_CH4sal, kind="bar")

# %%
sns.factorplot(x="Restoration", y="values", hue="type",data=concat_columns(["Fe","Mn"]), kind="bar")

# %%
dft = Sal_meta[["Restoration","CH4_m2_lin","Salinity_lin"]]
#sns.pairplot(x_vars=["Restoration"],y_vars=["CH4_m2_lin","Salinity_lin"],data=Sal_meta)
#g = sns.factorplot(x="values", y="Restoration", col="type", data=dft,kind="box",col_wrap=2)
fig, axes = plt.subplots(2,1,figsize=(4.5,9))
ax1 = sns.boxplot(x="Restoration", y="CH4_m2_lin",data=dft,ax=axes[0])
ax1.set_xlabel("")
ax1.set_ylabel("CH4 (ug/m2/h)",fontsize=18)
ax1.tick_params(axis='x', which='major', labelsize=15)
ax2 = sns.boxplot(x="Restoration", y="Salinity_lin",data=dft,ax=axes[1])
ax2.set_xlabel("")
ax2.set_ylabel("Salinity (psu)",fontsize=18)
ax2.tick_params(axis='x', which='major', labelsize=15)

# %%
sns.lmplot(x='Cl',y='CH4_pos',data=Sal_meta,hue='Restoration',fit_reg=False,size=3)
#plt.ylim([1, 3.4188381812483177])
plt.gca().set_yticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_yticks()]) 
plt.gca().set_xticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_xticks()]) 
plt.xlabel("Cl (ug/ml)", fontsize=18)
plt.ylabel("CH4 (ug/m2/h)",fontsize=18)

# %%
2**20
# Out:
# 1048576

# %%
sns.lmplot(x='Salinity',y='CH4_pos',data=Sal_meta,hue='Restoration',fit_reg=False,size=4)
plt.gca().set_yticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_yticks()]) 
plt.gca().set_xticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_xticks()]) 
plt.xlabel("Cl (ug/ml)", fontsize=18)
plt.ylabel("CH4 (ug/m2/h)",fontsize=18)

# %%
dfSO4 = concat_columns(["SO4_S"])
dfSO4["values"] = 10**dfSO4["values"]
plt.figure(figsize=(4.5,4))
sns.boxplot(x="Restoration", y="values",data=dfSO4)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.ylabel("SO4 (mg/L)",fontsize=18)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.xlabel("")

# %%
#sns.factorplot(x="Restoration", y="values", hue="type",data=concat_columns(["NP_ext"]), kind="bar")
#g = sns.pairplot(y_vars=["CH4_pos"], x_vars = ["NP_ext","Olsen_P"], hue='Restoration', data=Sal_meta,size=4)

#ax.get_yaxis().set_major_formatter(                                       # not scientific label
    #ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
sns.lmplot(y="CH4_pos", x = "NP_ext", hue='Restoration',fit_reg=False, data=Sal_meta,size=4)
#plt.yticks([-0.5,  0. ,  1. ,  2. ,  3.5])
#plt.xlim([1.5,5])
plt.gca().set_yticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_yticks()]) 
plt.gca().set_xticklabels(['{:,}'.format(int(10**x)) for x in plt.gca().get_xticks()]) 
plt.xlabel("Inorganic NP ext", fontsize=18)
plt.ylabel("CH4 (ug/m2/h)",fontsize=18)
plt.gca().get_xticks()
# Out:
# array([ 1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5])

# %% [markdown]
# ## Import Gene abundance table(s)

# %%
# Import and clean table

# Not normalized (included gene names)
#Salt_pond_KO= pd.read_csv('Salt_pond_KO_ordered.txt', sep='\t', index_col=0)

# Get gene fxns (TODO, maybe not needed)

# DESeq2 normalized 
Salt_pond_KO_DSq = pd.read_csv('Salt_pond_KO_ordered_DESeq2.txt', sep='\t', index_col=0)


## ABSTRACTION  @@@@@@@@@@  ANNOT. Selector
Gene_abund = Salt_pond_KO_DSq                     ## MG_RAST_KO SELECT
del Gene_abund.index.name   # Drop row index name before transpose
Gene_abundT = Gene_abund.T  # TRANSPOSE, samples as rows for join with ENV# Gene_abundT.head()

# Gene_abundT.head() 
# Gene_list = Gene_abundT.columns  # Get gene list (for later)  -- acting wonky, no methods could be use
# mgRAST_KO_de
(2 ** Gene_abundT)
# Out:
#                 K00001       K00002       K00003       K00004      K00005  \
# R2A_A_D1   2791.838940   366.787331  1847.040775   385.503460  172.338354
# R2A_A_D2   2594.066952   239.453216  1797.779042   345.442074  129.239208
# R2A_B_D1   2902.338348   232.695580  1797.779042   365.923941  181.270456
# R2A_B_D2   2052.263127   199.010398  1748.618679   426.351641  258.603860
# R2A_C_D1   2674.400844   194.509930  2022.606564   407.032448  264.917621
# R2A_C_D2   2447.341988   199.037988  1955.063837   444.518607  314.910925
# SF2_A_D1   2065.105828   345.825394  1637.183141   479.006028  320.793255
# SF2_A_D2   2510.919393   308.751000  1896.337454   558.030436  395.490711
# SF2_B_D1   2551.270227   473.165147  2105.577117   649.011396  376.420137
# SF2_B_D2   2674.400844   479.304940  2323.364833   684.022514  401.456538
# SF2_C_D1   2299.333472   320.082502  1937.526060   545.335400  423.347923
# SF2_C_D2   3371.091334   337.606764  2029.628546   673.764217  356.633891
# R1_A_D1    3160.637799  1437.155047  2704.225978   416.565630  445.505675
# R1_A_D2    3193.671035  1440.146637  2471.206748   357.326723  384.036600
# R1_B_D1    3538.690816  1163.293967  2736.279713   555.060031  471.168735
# R1_B_D2    3140.982087  1088.405171  2405.298117   371.289318  465.939878
# R1_C_D1    3008.857361   988.981689  1573.760186   411.372060  300.891596
# R1_C_D2    2486.671123   868.992551  1662.340262   375.325890  296.481854
# R2_A_D1     155.266201   119.196660   155.266201    70.953404   75.635939
# R2_A_D2   10347.538529  3899.301513  4377.829340  1056.443576  430.568808
# R2_B_D1    2870.328216   888.298041  1964.572916   372.914220  293.822283
# R2_B_D2    2719.263044   595.228584  2157.283402   387.512758  368.494685
# R2_C_D1    2967.433533   995.308532  2018.405042   258.603860  354.538871
# R2_C_D2    2036.674905   524.064291  1536.039925   307.768122  294.433905
#
#               K00006      K00007       K00008      K00009       K00010  \
# R2A_A_D1   47.304319   31.831870  1527.545883  190.295812  1016.433419
# R2A_A_D2   15.920348   67.340382  1584.706553  133.611465  1013.267938
# R2A_B_D1   48.573583   45.433987  1475.512063  135.486003  1046.241365
# R2A_B_D2   38.945912   38.945912  2072.275356  218.441022   805.421403
# R2A_C_D1   26.741343  101.469336  1645.146105  124.672546   989.050243
# R2A_C_D2   21.282563   44.072291  1983.730052  280.372298   947.446060
# SF2_A_D1   52.531104   63.579951  2270.823718  228.460351   784.919015
# SF2_A_D2   20.879279   51.886956  2813.207006  261.234205   939.728374
# SF2_B_D1   11.872896   45.807121  2815.157649  269.081613   915.934105
# SF2_B_D2   48.901269   31.105548  2866.351853  283.538336   853.945389
# SF2_C_D1   54.308270   48.459244  2846.552514  303.952063   899.637507
# SF2_C_D2   54.868263   26.813730  2776.400541  294.046396   813.952051
# R1_A_D1    12.031128   12.031128  1186.091834  177.564578   701.938099
# R1_A_D2    17.437242   12.031128  1123.667904  190.348580   661.868133
# R1_B_D1    26.813730   22.140256  1284.507857  210.780851  1036.137678
# R1_B_D2    17.437242   12.031128  1242.474046  167.265952   996.758367
# R1_C_D1    22.564767   17.437242  1031.837451  143.977544   661.868133
# R1_C_D2    12.888389   12.888389   781.336391  108.918107   699.121794
# R2_A_D1   136.229940   27.084583   203.600882   96.824484   265.892634
# R2_A_D2    58.806348   13.057438  1163.293967  160.352163   439.128695
# R2_B_D1    56.618436   11.716746  1219.437414  227.827802   639.987537
# R2_B_D2    73.920366   15.712055  1339.055461  181.861960   990.696950
# R2_C_D1    51.980550   11.872896  1172.197540  257.441352   797.864530
# R2_C_D2    45.048276   12.389104  1395.919470  224.940558   795.931244
#
#             ...         K19778     K19781     K19783      K19784     K19785  \
# R2A_A_D1    ...      11.114722  11.114722  35.280522  388.131039  11.114722
# R2A_A_D2    ...      11.234002  11.234002  45.232882  357.524922  39.159760
# R2A_B_D1    ...      11.803968  11.803968  57.194321  374.131078  17.006331
# R2A_B_D2    ...      17.136493  11.872896  35.182839  372.294373  11.872896
# R2A_C_D1    ...      11.851518  11.851518  48.843680  448.076111  31.066763
# R2A_C_D2    ...      11.555438  11.555438  25.749991  491.041109  25.749991
# SF2_A_D1    ...      11.964598  11.964598  22.387166  177.650754  22.387166
# SF2_A_D2    ...      36.709969  11.405834  25.246299  238.360274  16.248110
# SF2_B_D1    ...      22.140256  11.872896  35.182839  233.406350  11.872896
# SF2_B_D2    ...      11.861380  11.861380  38.891959  259.411747  17.113940
# SF2_C_D1    ...      11.783531  11.783531  45.327039  186.263347  11.783531
# SF2_C_D2    ...      11.872896  11.872896  48.969108  340.804364  11.872896
# R1_A_D1     ...      12.031128  12.031128  39.687148  564.292749  12.031128
# R1_A_D2     ...      12.031128  12.031128  35.862397  577.189002  12.031128
# R1_B_D1     ...      11.872896  11.872896  31.150858  789.393046  11.872896
# R1_B_D2     ...      12.031128  22.564767  22.564767  796.483133  12.031128
# R1_C_D1     ...      12.031128  12.031128  31.759141  527.453463  12.031128
# R1_C_D2     ...      12.888389  12.888389  12.888389  624.431713  12.888389
# R2_A_D1     ...      17.291606  17.291606  17.291606   17.291606  17.291606
# R2_A_D2     ...      13.057438  13.057438  13.057438  215.448613  13.057438
# R2_B_D1     ...      11.716746  11.716746  48.071170  444.888501  11.716746
# R2_B_D2     ...       9.514316  12.678393  26.923611  695.014853  18.666765
# R2_C_D1     ...      11.872896  11.872896  17.136493  535.706875  11.872896
# R2_C_D2     ...      12.389104  12.389104  33.119294  423.406615  12.389104
#
#              K19787     K19788      K19789     K19791     K19792
# R2A_A_D1  24.253146  31.831870  236.664581  11.114722  11.114722
# R2A_A_D2  15.920348  50.759291  260.474801  24.658275  11.234002
# R2A_B_D1  17.006331  34.886573  272.535433  26.584253  11.803968
# R2A_B_D2  11.872896  38.945912  332.267183  35.182839  11.872896
# R2A_C_D1  11.851518  45.689793  278.667317  42.364972  11.851518
# R2A_C_D2  11.555438  33.796455  309.758487  58.133586  16.532122
# SF2_A_D1  22.387166  49.491196  289.415825  11.964598  11.964598
# SF2_A_D2  16.248110  43.246156  345.154863  11.405834  11.405834
# SF2_B_D1  11.872896  38.945912  371.263583  17.136493  11.872896
# SF2_B_D2  17.113940  38.891959  416.652261  26.774728  11.861380
# SF2_C_D1  11.783531  30.807293  335.949367  21.900623  11.783531
# SF2_C_D2  17.136493  48.969108  429.376672  17.136493  11.872896
# R1_A_D1   12.031128  46.656300  615.706932  12.031128  12.031128
# R1_A_D2   12.031128  66.611529  628.469970  12.031128  12.031128
# R1_B_D1   11.872896  11.872896  461.280342  17.136493  11.872896
# R1_B_D2   12.031128  39.687148  472.051352  12.031128  12.031128
# R1_C_D1   12.031128  35.862397  647.124730  22.564767  12.031128
# R1_C_D2   12.888389  12.888389  369.159378  12.888389  12.888389
# R2_A_D1   17.291606  17.291606   17.291606  17.291606  17.291606
# R2_A_D2   30.660302  30.660302  680.192836  13.057438  13.057438
# R2_B_D1   21.719214  44.957815  580.478974  11.716746  11.716746
# R2_B_D2   15.712055  46.449785  604.626332   9.514316  12.678393
# R2_C_D1   22.140256  38.945912  603.161277  11.872896  11.872896
# R2_C_D2   28.516006  58.057076  520.877388  23.519737  12.389104
#
# [24 rows x 13752 columns]

# %% [markdown]
# ## Import ontology

# %% [markdown]
# # New ontology IMPORT

# %%
# Import NPS genes  -- ORIGINAL IMPORT
# NPS_KO = pd.read_csv('CNPS_CH4_KOs_WHH_Aug_2017.txt', sep='\t')
# NPS_KO = NPS_KO.iloc[:,:8]

# Import CNPS, CH4, Ferment genes
CNPSch4_Fm_KO = pd.read_csv('Ontology_KO_CNPSch4_Fm_whh0.txt', sep='\t', index_col=0)
CNPSch4_Fm_KO

### ABSTRACTION ### call gene_ontol
gene_ontol = CNPSch4_Fm_KO

# Check size, unique labels
gene_ontol.shape            # 527
gene_ontol.columns 
len(gene_ontol.mid_name.unique()) 
mid_u = gene_ontol.mid_name.unique() 
len(gene_ontol.mid_name.unique()) # 526, one repeated...not bad

# Make new sort and index vars
x = pd.Series(range(1,len(gene_ontol),1))    # create series 1:n
s =x.astype(str)                             # make string
gene_ontol['KO_order'] = x                   # num for sort
gene_ontol['KO_order_S'] = s               # num string for print                       # gene_ontol.shape
gene_ontol.head()
#gene_ontol.columns

########################
## ADD Abbrev. NAMES
Ont = gene_ontol         # Rename Ont shorter
gene_ontol['sm_name'] = (Ont['KO']+ " " + Ont['L3'] + " " + Ont['gene'].str[:4])
gene_ontol['mid_name'] = (Ont['KO']+ " " + Ont['L3'] + " ( " + Ont['gene'].str[:4] + " ) " + Ont['fxn'].str[:18])
gene_ontol.tail()
# Out:
#                L1       L2        L3  L4            KO       gene  \
# 185  Fermentation  Acetate  Acetogen NaN  K00925             ackA
# 186  Fermentation  Acetate  Acetogen NaN       K04020        eutD
# 187  Fermentation  Acetate  Acetogen NaN        K00640       cysE
# 188  Fermentation  Acetate  Acetogen NaN        K13598       ntrY
# 189  Fermentation  Acetate  Acetogen NaN        K01905  E6.2.1.13
#
#                                                    fxn             EC  \
# 185                                     acetate_kinase   [EC:2.7.2.1]
# 186                              phosphotransacetylase            NaN
# 187                         serine O-acetyltransferase  [EC:2.3.1.30]
# 188  two-component system, NtrC family, nitrogen re...  [EC:2.7.13.3]
# 189                acetyl-CoA synthetase (ADP-forming)  [EC:6.2.1.13]
#
#                         sm_name  \
# 185  K00925       Acetogen ackA
# 186       K04020  Acetogen eutD
# 187        K00640 Acetogen cysE
# 188        K13598 Acetogen ntrY
# 189        K01905 Acetogen E6.2
#
#                                           mid_name  KO_order KO_order_S
# 185  K00925       Acetogen ( ackA ) acetate_kinase       186        186
# 186   K04020  Acetogen ( eutD ) phosphotransacetyl       187        187
# 187    K00640 Acetogen ( cysE ) serine O-acetyltra       188        188
# 188    K13598 Acetogen ( ntrY ) two-component syst       189        189
# 189    K01905 Acetogen ( E6.2 ) acetyl-CoA synthet       190        190

# %%
### Import Gene colors
gene_colors = pd.read_csv('Ontol_KO_L2_Color_KEY_whh0.txt', sep='\t', index_col=0)         
# gene_colors = gene_colors.iloc[:,4:6]                                  # why not keep it all and drop later?        # get L3 colors and cats    # gene_colors

#### Merge colors, Ontol
gene_ontol_colors = pd.merge(gene_ontol, gene_colors, on = 'L2', how='inner')  # Here changed to L2
# gene_colors.head()
# gene_ontol_colors
gene_colors
# Out:
#                   L2    color
# 0             Sugars  #e94c3e
# 1           Polymers  #b8302a
# 2           Aromatic  #5f3230
# 3    Denitrification  #93ce81
# 4      NO3_reduction  #6bb96d
# 5      NH3_oxidation  #41a359
# 6    NO3_A.reduction  #36854d
# 7   NH4_assimilation  #356542
# 8        N2_fixation  #344338
# 9        P_transport  #4e96c8
# 10      P_regulation  #3787c0
# 11       PolyP-ases   #3676a4
# 12     Phosphatases   #356587
# 13     Phn_transport  #35556c
# 14   CH3-phosphonate  #34434f
# 15    S2O3_oxidation  #e975a8
# 16   SO4_D.reduction  #ce248f
# 17   SO4_A.reduction  #8f296a
# 18     CH4_oxidation  #d9d9d9
# 19  CH4_H2_reduction  #b0b0b0
# 20       CH4_acetate  #7e7e7e
# 21  CH4_methylotroph  #515151
# 22      CH4_Archaeal  #181818
# 23   CH3_Phosphonate  #34434f
# 24      H2_oxidation  #fed778
# 25     H2_production  #fe9829
# 26      Fermentation  #d85a09
# 27           Acetate  #8e3104

# %% [markdown]
# ## Subset Ontology

# %%
### Get gene cycle subsets
gene_ontol_colors.head()
gene_ontol_colors.L1.unique()

Carbon = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('Carbon')]             # L1 = Carbon 
Nitrogen = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('Nitrogen')]         # L1 = Nitrogen
Phosphorus = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('Phosphorus')]     # L1 = Phosphorus
Sulfur = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('Sulfur')]             # L1 = Sulfur
CH4_cycling = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('CH4_cycling')]   # L1 = CH4 
Fermentation = gene_ontol_colors[gene_ontol_colors['L1'].str.contains('Fermentation')] # L1 = Fermentaiton

NPS_CH4_LIST = [Nitrogen, Phosphorus, Sulfur, CH4_cycling]
# NPS_CH4 = pd.concat([NPS_CH4_LIST], 0) 

NPS_CH4 = pd.concat([Nitrogen, Phosphorus, Sulfur, CH4_cycling], 0) 

# gene_ontol_colors.tail()

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@
# # Select Gene ONTOL by cycle

# %%
#   [[[ ON / OFF ]]]            # by commenting out -- NOTE Sequence will matter if [[[ ON ]]]

# gene_ontol_colors = Nitrogen
# gene_ontol_colors = CH4_cycling
gene_ontol_colors = NPS_CH4

gene_ontol_colors.L1.unique()   # gene_ontol_colors.L2.unique()
# Out:
# array(['Nitrogen', 'Phosphorus', 'Sulfur', 'CH4_cycling'], dtype=object)

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@
# # Set Correlation Cutoff Params

# %%
# SET global CORRELATION CUTOFFS: 
# DEF parameters: Out_var, cutoff 

### OUT_VAR - variable to cut off on
out_var = 'Salinity'  
# out_var = 'Cl' 

#out_var = 'CH4_pos'
# out_var = 'CH4_umol_m2_d' 

# out_var = 'CH4_m2_lin' 
# out_var = 'CO2_mg_m2_h'  
# out_var = 'DOC_mg_L'  
# out_var = 'C'  
# out_var = 'N_g_m2'  

###  r_cut - correlation CUTOFF value
r_cut = 0.5        # corr coefficient cutoff (abs. val.) 

## FIG SIZE
figdim = (10,10)           # plot size

out_var
# Out:
# 'Salinity'

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@
# # RUN script below

# %% [markdown]
# ### PROCESS DATA for Heatmap
# 1): Join [Genes, Env], corr. subset;
#
# 2): Merge [Genes, Env] with [Gene Ontology / Colors]
#
# 3): Cutoff subset
#
# 4): Get data matrix, colors for heatmap

# %% [markdown]
# ### PLOT heatmap after proc. data

# %%
### 1) Make [Genes, Env] Correlation matrix:  merge, corr, subset NR

Gene_abundT = Gene_abund.T                                    # Transpose before join
Genes_env = Env_chem.join(Gene_abundT, how='right')           # JOIN genes and metadata
Genes_env_corr = Genes_env.corr()                             # Make CORR matrix

# Subset Corr matrix by [Genes, Env]                           
n_enVars = len(env_chem_List)                                 # get n Env_vars
Genes_env_CORR = Genes_env_corr.iloc[n_enVars:,:n_enVars]     # reduce Corr.M to include only [Genes, Env] 

### Merge [Genes, Env] corretlation matrix with Gene ontology 
# Prep corr matrix, set KO col, drop index
Genes_env_CORR['KO']= Genes_env_CORR.index                  # M1: Set KO as column, drop index
Genes_env_CORr = Genes_env_CORR.reset_index(drop=True)      # Drop index      
Genes_env_CORr.head() # Genes_env_CORr.shape
# Out:
#    Salinity  Cond_uS_cm      Temp   DO_perc   DO_mg_L     Redox    pH_YSI  \
# 0 -0.074759   -0.070217 -0.080049 -0.112672  0.017819 -0.280717  0.070289
# 1  0.575822    0.568306  0.041587 -0.396216 -0.645770  0.204430  0.278701
# 2 -0.156208   -0.151800 -0.157153 -0.164075  0.044040 -0.395241  0.020051
# 3 -0.388098   -0.399151 -0.468068 -0.178808  0.127426 -0.208312 -0.374258
# 4  0.024669    0.004996 -0.488337 -0.479029 -0.330930 -0.396233 -0.280833
#
#    CH4_umol_m2_d  CO2_umol_m2_d   CH4_CO2   ...          Mg        Zn  \
# 0      -0.013013       0.007434  0.014791   ...    0.125575  0.396682
# 1       0.526049       0.393946  0.437543   ...    0.682640  0.738606
# 2      -0.059631      -0.022533 -0.052988   ...    0.072453  0.410166
# 3      -0.415069      -0.364641 -0.335307   ...   -0.196199  0.248937
# 4      -0.178794      -0.063907 -0.143379   ...    0.231890  0.593648
#
#          Mn        Cu        Fe  CH4_m2_lin  CO2_m2_lin  Salinity_lin  \
# 0  0.143343  0.444992  0.316210   -0.045501   -0.037747     -0.126783
# 1  0.246013  0.020201 -0.352505    0.553546    0.399363      0.507924
# 2  0.129345  0.516188  0.354780   -0.077457   -0.046677     -0.219726
# 3 -0.151544  0.540492  0.523103   -0.328322   -0.416521     -0.401769
# 4  0.035916  0.356674  0.091906    0.126892   -0.135322     -0.031568
#
#      pH_lin      KO
# 0 -0.065867  K00001
# 1  0.517657  K00002
# 2 -0.043680  K00003
# 3  0.012413  K00004
# 4  0.372937  K00005
#
# [5 rows x 45 columns]

# %%
#Genes_env.corr(method='spearman')
Genes_env.T.to_csv("/Users/jzz0026/Google_superjohnlove/jupyter/Saltpond/Wyatt_C-P_CH402/env_gene_deseq.csv")
#CNPSch4_Fm_KO

# %%
#Genes_env_CORr

# %%
# MERGE on KO, while keeping duplicates, drop NA
Genes_env_ontol_Corr= pd.merge(gene_ontol_colors, Genes_env_CORr, on = 'KO', how='left')    #  Merge
#Genes_env_ontol_Corr = Genes_env_ontol_Corr.dropna(how='all', subset= env_chem_List)        # Drop NA in Env by index
# Genes_env_ontol_Corr.iloc[:,:20]
#Genes_env_ontol_Corr.dropna(how='all', subset= env_chem_List)
del env_chem_List[11]

# %%
### 2) Merge [Genes, Env] with [Gene Ontology/colors]

# MERGE on KO, while keeping duplicates, drop NA
Genes_env_ontol_Corr= pd.merge(gene_ontol_colors, Genes_env_CORr, on = 'KO', how='left')    #  Merge
#Genes_env_ontol_Corr = Genes_env_ontol_Corr.dropna(how='all', subset= env_chem_List)        # Drop NA in Env by index
# Genes_env_ontol_Corr.iloc[:,:20]

# RE-INDEX matrix by GENE NAMES -- must be unique, here MID_NAME
Genes_env_ontol_CorN = Genes_env_ontol_Corr.reset_index(drop=True)    # Drop index           
Genes_env_ontol_CorN = Genes_env_ontol_Corr.set_index('mid_name',0)   # RENAME index: Needs UNIQUE index, hence L3 
del Genes_env_ontol_CorN.index.name                                   # delete index name

# %%
### 3) get CUTOFF data
# Make Absolute Value var
abs_var = "abs_"+ out_var     
abs_var

# append Abs. Value to matrix
Genes_env_ontol_CorN[abs_var] = abs(Genes_env_ontol_CorN[out_var])  
Genes_env_ontol_CorN.head()  # Genes_env_ontol_Corr.shape

# Cutoff at data |r| > cut                                                              
# Print string with abs_var, exec -- abstraction workaround
Cut_CALL = 'Genes_env_ontol_Corr_cut = Genes_env_ontol_CorN[Genes_env_ontol_CorN.'+ abs_var +' > r_cut]'
Cut_CALL
exec(Cut_CALL)    # Genes_env_ontol_Corr_cut

# %%
### 4) Get data ONLY Matrix
### Make data only matrix for heatmap
n_ontol = len(gene_ontol_colors.columns)                            # get length of onotlogy map - to subtract 
Genes_env_ontol_CorrM = Genes_env_ontol_Corr_cut.iloc[:,n_ontol:]   # Drop onlology variables 
#Genes_env_ontol_CorrM = Genes_env_ontol_CorrM.iloc[:,1:]            # Drop new KO column, was index in ontology
Genes_env_ontol_CorrM = Genes_env_ontol_CorrM.iloc[:,:-1]           # Drop column w abs. val

gene_colors = Genes_env_ontol_Corr_cut['color']                     # Gets gene colors --- Changed from L3 in initial
Genes_env_ontol_CorrM["Salinity"].sort_values(ascending=False)
# Out:
# K06162 P_CH3_Phn ( phnM ) alpha-D-ribose 1-m       0.832495
# K06164 P_CH3_Phn ( phnI ) alpha-D-ribose 1-m       0.748894
# K06163 P_CH3_Phn ( phnJ ) alpha-D-ribose 1-m       0.732015
# K06163 CH3_Phn ( phnJ ) alpha-D-ribose 1-m         0.732015
# K06166 P_CH3_Phn ( phnG ) alpha-D-ribose 1-m       0.715333
# K06165 P_CH3_Phn ( phnH ) alpha-D-ribose 1-m       0.705038
# K00581 CH4_Archa ( mtrE ) tetrahydromethanop       0.666860
# K00399 CH4_Archa ( mcrA ) methyl-coenzyme M        0.663318
# K02042 P_Phn ( phnE ) phosphonate transp           0.643999
# K05780 P_CH3_Phn ( phnL ) alpha-D-ribose 1-m       0.634348
# K00580 CH4_Archa ( mtrD ) tetrahydromethanop       0.616489
# K01514 P_PolyPase ( PRUN ) exopolyphosphatase      0.612644
# K00401 CH4_Archa ( mcrB ) methyl-coenzyme M        0.595856
# K00579 CH4_Archa ( mtrC ) tetrahydromethanop       0.593559
# K00402 CH4_Archa ( mcrG ) methyl-coenzyme M        0.590672
# K14082 CH4_methylam ( mtbA ) [methyl-Co(III) me    0.589383
# K00578 CH4_Archa ( mtrB ) tetrahydromethanop       0.535155
# K02041 P_Phn ( phnC ) phosphonate transp           0.514302
# K00582 CH4_Archa ( mtrF ) tetrahydromethanop       0.505637
# K11083 P_Phn ( phnU ) 2-aminoethylphosph          -0.513337
# K00373 NO3_red ( narJ ) nitrate reductase         -0.515262
# K02588 N2_fix ( nifH ) nitrogenase iron p         -0.517614
# K14083 CH4_methylam ( mttB ) trimethylamine---c   -0.520082
# K01083 P_P-ase ( E3.1 ) 3-phytase                 -0.537207
# K07637 P_regulat ( phoQ ) two-component syst      -0.541034
# K05306 P_Phn ( phnX ) phosphonoacetaldeh          -0.546975
# K17877 NO3_A.red ( NIT- ) nitrite reductase       -0.559274
# K03388 CH4_Archa ( hdrA ) heterodisulfide re      -0.568184
# K02591 N2_fix ( nifK ) nitrogenase molybd         -0.572250
# K13788 CH4_acetat ( pta ) phosphate acetyltr      -0.576018
#                                                      ...
# K01953 NH4_asim ( asnB ) asparagine synthas       -0.641753
# K15371 NH4_asim ( GDH2 ) glutamate dehydrog       -0.652398
# K00362 NO3_D.red ( nirB ) nitrite reductase       -0.669333
# K00200 CH4_H2.red ( fwdA ) formylmethanofuran     -0.687691
# K11181 SO4_D.red ( dsrB ) sulfite reductase       -0.718546
# K14080 CH4_methanol ( mtaA ) [methyl-Co(III) me   -0.725326
# K11180 SO4_D.red ( dsrA ) sulfite reductase       -0.733406
# K03430 P_Phn ( phnW ) 2-aminoethylphosph          -0.742714
# K10945 CH4_ox ( pmoB ) methane/ammonia mo         -0.748642
# K10945 NH3_oxid ( pmoB ) methane/ammonia mo       -0.748642
# K00392 SO4_A.red ( sir ) sulfite reductase        -0.752111
# K10944 NH3_oxid ( pmoA ) methane/ammonia mo       -0.753839
# K10944 CH4_ox ( pmoA ) methane/ammonia mo         -0.753839
# K03390 CH4_Archa ( hdrC ) heterodisulfide re      -0.761468
# K01093 P_P-ase ( appA ) 4-phytase / acid p        -0.763035
# K03389 CH4_Archa ( hdrB ) heterodisulfide re      -0.763225
# K00201 CH4_H2.red ( fwdB ) formylmethanofuran     -0.767057
# K10946 CH4_ox ( pmoC ) methane/ammonia mo         -0.779390
# K10946 NH3_oxid ( pmoC ) methane/ammonia mo       -0.779390
# K00394 SO4_D.red ( aprA ) adenylylsulfate re      -0.791610
# K00395 SO4_D.red ( aprB ) adenylylsulfate re      -0.805472
# K07768 P_regulat ( senX ) two-component syst      -0.820948
# K00367 NO3_A.red ( narB ) ferredoxin-nitrate      -0.826897
# K00577 CH4_Archa ( mtrA ) tetrahydromethanop      -0.843258
# K07776 P_regulat ( regX ) two-component syst      -0.852482
# K02568 NO3_red ( napB ) cytochrome c-type         -0.862274
# K07221 P_transp ( oprO ) phosphate-selectiv       -0.865105
# K00264 NH4_asim ( GLT1 ) glutamate synthase       -0.873036
# K02567 NO3_red ( napA ) periplasmic nitrat        -0.876094
# K10535 NH3_oxid ( hao ) hydroxylamine dehy        -0.932554
# Name: Salinity, Length: 71, dtype: float64

# %%
### 5) PLOT heatmap

# PLOTTING Params
# plt.rcParams["figure.figsize"] = (8, 4)
# figdim = (10,10)     # wonky?
# fig.set_size_inches(11.7, 8.27)

cm=sns.clustermap(Genes_env_ontol_CorrM, vmax=0.8, row_cluster=False, col_cluster=True, 
             square=False, row_colors=gene_colors, figsize = (10,13));          # , figsize = (10,20))         
plt.setp(cm.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)   # rotate ticks
plt.show()                  
# plt.sca(cm.ax_heatmap) # More on this in a minute
# plt.yticks(rotation=0)

# %% [markdown]
# # GET BEST CORRs

# %%
# Genes_env_ontol_Corr_cut.head()                      # Starting point from corr matrix
out_varS = ['KO', out_var, abs_var]                    # List vars to get          
corr_out_varS = Genes_env_ontol_Corr_cut[out_varS]     # get vars from CORR MTX

## Sort by abs
# corr_out_varSabs = corr_out_varS.sort_values(by=out_var, ascending =0)    # make abs col
# corr_out_varSabs

## Sort by corr +/-
corr_out_varSout_PLUS= corr_out_varS.sort_values(by=out_var, ascending =0)    # make abs col

# Get 5 most pos/most neg
Max_corr5 = corr_out_varSout_PLUS.head(5)  # 5 largest
Min_corr5 = corr_out_varSout_PLUS.tail(5)  # 5 smallest 

# Combine Top 10
top10 = [Max_corr5, Min_corr5]             # Make list
Top10_data = pd.concat(top10)              # Concat list
# Top10_data

##### Get TOP 10 GENES                     # May not need, redo at end?
# Top10_genes = Top10_data.index
# Top10_genes
# corr_out_varSout_PLUS

# %% [markdown]
# # PLOT TOP 10 VARS

# %% [markdown]
# ###  Modified to accomodate short names for plots

# %%
# Prepare plots
# Site_or = ('Sandmound','WestPond','Mayberry','Browns','RushRanch','Joice','Goodyear','WhiteSlough','Tolay','ChinaCamp','Muzzi')

## Get environment Metadata                                         # Sal_meta.columns # metacols = ['Sample','Location']
metacols = ['New_index', 'Sample_name', 'Sample', 'Site', 'Core', 'Depth',
       'Restoration', 'Hydrol']

Metadata = Sal_meta[metacols]                                       # Note SAL_META here, not env, was dropped 
Metadata.set_index('Sample', inplace=True)                          # added back samp indexes 
del Metadata.index.name                                             # drop index name    

#### Rename GENEs in Gene_abund         Gene_abund.head()
Gene_abundN = Gene_abund.copy()                                     # Makes copy 
Gene_abundN['KO'] = Gene_abundN.index                               # Get KO from index
Gene_abundN = Gene_abundN.reset_index(drop=True)                    # Drop index

# Merge with TOP 10 by KO
# Gene_abundN.head()

# %%
# get SMALL names for scatterplots                           #gene_ontol_colors.head()
names = ['sm_name', 'mid_name']                               # get name translation list 
rename = gene_ontol_colors[names]                             # get sm_name, mid_name DF 
sm_name = rename.set_index('mid_name')                        # del sm_name.index.name # sm_name

# Get Top 10 KOs, with Corr.
getvars = ['KO',out_var]
# Top_10_KOs = pd.DataFrame(Top10_data[getvars])                                 # DEFUNCT  # Get top 10 KOs, index
Top_10_KOs = Top10_data[getvars]

# Top_10_KOs_renamer
Top_10_KOs_rename = Top_10_KOs.join(sm_name)                  # Join with Top 10 KOs
Top_10_KOs_sm_name = Top_10_KOs_rename.set_index('sm_name')   # Reset index 
del Top_10_KOs_sm_name.index.name                             # Del index name   
Top_10_KOs_smN = Top_10_KOs_sm_name                           # shorten var

# %%
# Merge TOP 10 with Gene_abund, by KO
Gene_abund_top10 = pd.merge(Top_10_KOs_smN, Gene_abundN, on='KO', how='left') # Merge with Gene_abund
Gene_abund_top10.index = Top_10_KOs_smN.index                                 # Reindex
Gene_abund_top10 = Gene_abund_top10.iloc[:,2:]                                # Drop KOs, corr

# Transpose and Rejoin with Environ data (including meta)
Gene_abund_top10T = Gene_abund_top10.T 

## Join Meta with samples / genes                                             # with prior [Genes x Env matrix]  # Genes_env.head()
Env_gene_abund_Top10 = Genes_env.join(Gene_abund_top10T, how='right')         # JOIN Top genes with soil chem.
Meta_Env_gene_abund_Top10 = Metadata.join(Env_gene_abund_Top10, how = 'left') # Join metadata

# %% [markdown]
# # Top 10 variable scatterplots

# %%
# Prepare plots
# Top 10 needs sorting after several merges
Top_10_KOs_smN.columns = ['KO','Corr']                                    # Rename abstract var
Top_10_KOs_smN = Top_10_KOs_smN.sort_values('Corr',0, ascending=False)    # Sort by corr

# Get just list of genes for plots
Top10_genes = Top_10_KOs_smN.index

# Color params:
# sns.set_style("white")
# sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})

Top10_genes
Top_10_KOs_smN
Top_10_KOs
# Out:
#                                                   KO  Salinity
# K06162 P_CH3_Phn ( phnM ) alpha-D-ribose 1-m  K06162  0.832495
# K06164 P_CH3_Phn ( phnI ) alpha-D-ribose 1-m  K06164  0.748894
# K06163 P_CH3_Phn ( phnJ ) alpha-D-ribose 1-m  K06163  0.732015
# K06163 CH3_Phn ( phnJ ) alpha-D-ribose 1-m    K06163  0.732015
# K06166 P_CH3_Phn ( phnG ) alpha-D-ribose 1-m  K06166  0.715333
# K02568 NO3_red ( napB ) cytochrome c-type     K02568 -0.862274
# K07221 P_transp ( oprO ) phosphate-selectiv   K07221 -0.865105
# K00264 NH4_asim ( GLT1 ) glutamate synthase   K00264 -0.873036
# K02567 NO3_red ( napA ) periplasmic nitrat    K02567 -0.876094
# K10535 NH3_oxid ( hao ) hydroxylamine dehy    K10535 -0.932554

# %% [markdown]
# ###  by LOCATION

# %%
sns.pairplot(y_vars=[out_var], x_vars = Top10_genes[0:5], hue='Restoration', data=Meta_Env_gene_abund_Top10)
sns.pairplot(y_vars=[out_var], x_vars = Top10_genes[5:11], hue='Site', data=Meta_Env_gene_abund_Top10)
# Top10_genes

# %% [markdown]
# ### By DEPTH

# %%
# Prepare plots
sns.pairplot(y_vars=[out_var], x_vars = Top10_genes[0:5], hue='Depth', data=Meta_Env_gene_abund_Top10)
sns.pairplot(y_vars=[out_var], x_vars = Top10_genes[5:11], hue='Depth', data=Meta_Env_gene_abund_Top10)

# %%
Sal_meta.columns
# Out:
# Index([u'New_index', u'Sample_name', u'Sample', u'Site', u'Core', u'Depth',
#        u'Restoration', u'Hydrol', u'Date', u'Lat', u'Long', u'Salinity',
#        u'Cond_uS_cm', u'Temp', u'DO_perc', u'DO_mg_L', u'Redox', u'pH_YSI',
#        u'CH4_umol_m2_d', u'CO2_umol_m2_d', u'CH4_CO2', u'CH4_pos',
#        u'CH4_CO2_pos', u'pH', u'Cl', u'SO4_S', u'TOC', u'OM_LOI', u'C_Org_LOI',
#        u'CaCO3', u'C', u'N', u'P', u'CN', u'CP', u'NP', u'NO3', u'NH4',
#        u'Olsen_P', u'NP_ext', u'NO3_NH4', u'K_ppm', u'K_meq', u'Na_ppm',
#        u'Na_meq', u'Ca', u'Mg', u'Zn', u'Mn', u'Cu', u'Fe', u'CH4_m2_lin',
#        u'CO2_m2_lin', u'Salinity_lin', u'pH_lin', u'NP_ext_lin', u'NP_lin',
#        u'Cl_lin'],
#       dtype='object')

# %%
Sal_meta_Gene_abund = pd.merge(Sal_meta,Gene_abundT,left_on="Sample",right_index=True,how="left")
#Genes_env["K06163"]
sns.pairplot(x_vars=["K00399","K06163","K10944"],y_vars='CH4_pos',data=Sal_meta_Gene_abund,hue='Restoration',size=3)


ax1 = sns.lmplot(x="K06163",y='Salinity_lin',data=Sal_meta_Gene_abund,hue='Restoration',fit_reg=False,size=3,aspect=1.2)
ax1.set(yscale='log')
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.ylabel("Salinity (ppt)",size=15)
plt.xlabel("K06163 phnJ",size=15)
ax1.ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))               # integer format 
plt.yticks([25,50,100,200]) 

ax2 = sns.lmplot(x="K06163",y='Cl',data=Sal_meta_Gene_abund,hue='Restoration',fit_reg=False,size=3)
ax2 = sns.lmplot(x="K06163",y='NP_ext',data=Sal_meta_Gene_abund,hue='Restoration',fit_reg=False,size=3)

#sns.lmplot(x="K06163",y='K_ppm',data=Sal_meta_Gene_abund,hue='Restoration',fit_reg=False,size=3)

# %%
chem_col = Sal_meta_Gene_abund.columns[12:57]
chem_col = Sal_meta_Gene_abund[chem_col].loc[:,~Sal_meta_Gene_abund[chem_col].isnull().any()].columns
chem_col = list(chem_col[:7]) + list(chem_col[8:])
#sns.pairplot(x_vars=['K06163'],y_vars=[chem_col],data=Sal_meta_Gene_abund,hue='Restoration',size=3)
Sal_meta_Gene_abund[Sal_meta_Gene_abund.columns[12:57]]
sns.pairplot(x_vars=chem_col,y_vars='K06163',data=Sal_meta_Gene_abund,hue='Restoration',size=3)

# %% [markdown]
# ## Gene abudance instead of correlation

# %%
Genes_env_ontol_CorrM_col = [a.split(" ")[0] for a in Genes_env_ontol_CorrM.index]
Gene_abund_high_corr = Gene_abund.loc[Genes_env_ontol_CorrM_col]
Gene_abund_high_corr["KO_fun"] = Genes_env_ontol_CorrM.index
Gene_abund_high_corr_rename = Gene_abund_high_corr.set_index("KO_fun")

blue = ["#003366"]
green = ["#009900"]
red = ["#CC0000"]
Restoration_color = blue*6 + green*6 + red * 12

#Gene_abund_high_corr_rename.columns
Restoration_color = pd.DataFrame(Restoration_color,Gene_abund_high_corr_rename.columns)
Restoration_color.columns = ["Restoration"]

# %%
cm=sns.clustermap(Gene_abund_high_corr_rename, row_cluster=False, col_cluster=False, 
             square=False, vmin=-2.5, vmax=2.5, row_colors=gene_colors,col_colors=Restoration_color,z_score=0, figsize = (10,13));          # , figsize = (10,20))         
plt.setp(cm.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)   # rotate ticks
plt.show()

# %%
#Gene_abund_high_corr_rename.index
Genes_env_ontol_CorrM.loc[:,["Salinity","CH4_pos"]]
cm2 = sns.clustermap(Genes_env_ontol_CorrM.loc[:,["Salinity","CH4_pos"]], row_cluster=False, col_cluster=False,
                     cmap="PiYG",square=False,figsize = (1,13)); 
plt.setp(cm2.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)   # rotate ticks

plt.show()

# %%
Genes_env_ontol_CorrM.loc[:,["Salinity","CH4_pos"]]
# Out:
#                                                  Salinity   CH4_pos
# K15864 N_DNT ( nirS ) nitrite reductase         -0.617613 -0.507925
# K00370 N_DNT ( narG ) nitrate reductase         -0.607241 -0.509563
# K00371 NO3_red ( narH ) nitrate reductase       -0.590419 -0.474416
# K00374 NO3_red ( narI ) nitrate reductase       -0.594756 -0.386905
# K00373 NO3_red ( narJ ) nitrate reductase       -0.515262 -0.365846
# K02567 NO3_red ( napA ) periplasmic nitrat      -0.876094 -0.751993
# K02568 NO3_red ( napB ) cytochrome c-type       -0.862274 -0.719783
# K00362 NO3_D.red ( nirB ) nitrite reductase     -0.669333 -0.655328
# K00363 NO3_D.red ( nirD ) nitrite reductase     -0.596148 -0.768371
# K10944 NH3_oxid ( pmoA ) methane/ammonia mo     -0.753839 -0.897643
# K10945 NH3_oxid ( pmoB ) methane/ammonia mo     -0.748642 -0.877186
# K10946 NH3_oxid ( pmoC ) methane/ammonia mo     -0.779390 -0.903666
# K10535 NH3_oxid ( hao ) hydroxylamine dehy      -0.932554 -0.828711
# K00367 NO3_A.red ( narB ) ferredoxin-nitrate    -0.826897 -0.873240
# K17877 NO3_A.red ( NIT- ) nitrite reductase     -0.559274 -0.727739
# K00264 NH4_asim ( GLT1 ) glutamate synthase     -0.873036 -0.779008
# K00284 NH4_asim ( E1.4 ) glutamate synthase     -0.634679 -0.512340
# K01953 NH4_asim ( asnB ) asparagine synthas     -0.641753 -0.518782
# K15371 NH4_asim ( GDH2 ) glutamate dehydrog     -0.652398 -0.619665
# K02588 N2_fix ( nifH ) nitrogenase iron p       -0.517614 -0.216672
# K02586 N2_fix ( nifD ) nitrogenase molybd       -0.624889 -0.391458
# K02591 N2_fix ( nifK ) nitrogenase molybd       -0.572250 -0.366332
# K07221 P_transp ( oprO ) phosphate-selectiv     -0.865105 -0.675607
# K07768 P_regulat ( senX ) two-component syst    -0.820948 -0.804852
# K07776 P_regulat ( regX ) two-component syst    -0.852482 -0.825428
# K07637 P_regulat ( phoQ ) two-component syst    -0.541034 -0.411942
# K01514 P_PolyPase ( PRUN ) exopolyphosphatase    0.612644  0.736746
# K01083 P_P-ase ( E3.1 ) 3-phytase               -0.537207 -0.486917
# K01093 P_P-ase ( appA ) 4-phytase / acid p      -0.763035 -0.671870
# K02042 P_Phn ( phnE ) phosphonate transp         0.643999  0.476871
# ...                                                   ...       ...
# K00394 SO4_D.red ( aprA ) adenylylsulfate re    -0.791610 -0.547230
# K00395 SO4_D.red ( aprB ) adenylylsulfate re    -0.805472 -0.541451
# K11180 SO4_D.red ( dsrA ) sulfite reductase     -0.733406 -0.475607
# K11181 SO4_D.red ( dsrB ) sulfite reductase     -0.718546 -0.454130
# K00392 SO4_A.red ( sir ) sulfite reductase      -0.752111 -0.862229
# K10944 CH4_ox ( pmoA ) methane/ammonia mo       -0.753839 -0.897643
# K10945 CH4_ox ( pmoB ) methane/ammonia mo       -0.748642 -0.877186
# K10946 CH4_ox ( pmoC ) methane/ammonia mo       -0.779390 -0.903666
# K00200 CH4_H2.red ( fwdA ) formylmethanofuran   -0.687691 -0.647070
# K00201 CH4_H2.red ( fwdB ) formylmethanofuran   -0.767057 -0.690809
# K13788 CH4_acetat ( pta ) phosphate acetyltr    -0.576018 -0.324707
# K00197 CH4_acetat ( cdhE ) acetyl-CoA decarbo   -0.608414 -0.280537
# K00194 CH4_acetat ( cdhD ) acetyl-CoA decarbo   -0.580979 -0.274445
# K14080 CH4_methanol ( mtaA ) [methyl-Co(III) me -0.725326 -0.392497
# K14082 CH4_methylam ( mtbA ) [methyl-Co(III) me  0.589383  0.780684
# K16178 CH4_methylam ( mtbB ) dimethylamine---co -0.591883 -0.248540
# K14083 CH4_methylam ( mttB ) trimethylamine---c -0.520082 -0.239636
# K00577 CH4_Archa ( mtrA ) tetrahydromethanop    -0.843258 -0.712289
# K00578 CH4_Archa ( mtrB ) tetrahydromethanop     0.535155  0.634780
# K00579 CH4_Archa ( mtrC ) tetrahydromethanop     0.593559  0.700069
# K00580 CH4_Archa ( mtrD ) tetrahydromethanop     0.616489  0.716704
# K00581 CH4_Archa ( mtrE ) tetrahydromethanop     0.666860  0.747123
# K00582 CH4_Archa ( mtrF ) tetrahydromethanop     0.505637  0.594440
# K00399 CH4_Archa ( mcrA ) methyl-coenzyme M      0.663318  0.771610
# K00401 CH4_Archa ( mcrB ) methyl-coenzyme M      0.595856  0.722357
# K00402 CH4_Archa ( mcrG ) methyl-coenzyme M      0.590672  0.701323
# K03388 CH4_Archa ( hdrA ) heterodisulfide re    -0.568184 -0.215947
# K03389 CH4_Archa ( hdrB ) heterodisulfide re    -0.763225 -0.452734
# K03390 CH4_Archa ( hdrC ) heterodisulfide re    -0.761468 -0.451095
# K06163 CH3_Phn ( phnJ ) alpha-D-ribose 1-m       0.732015  0.564501
#
# [71 rows x 2 columns]
