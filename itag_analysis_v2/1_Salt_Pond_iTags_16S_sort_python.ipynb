# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

# %%
otu_raw = pd.read_csv("../Salt_pond_16S_otu.tax.filtered.txt",sep="\t",index_col=0)

# Filter OTU table to > 99 reads  -- Note if AGG or Grep, Agg, don't used filtered.
otu_F100 = otu_raw[otu_raw.iloc[:,:-1].sum(1) > 99]
otu_F100.head()

## IMPORT Sample mapping, modified from TL
map_iTag = pd.read_csv("../Salt_pond_ALL_Meta_whh.txt", sep="\t")
map_iTag_only = map_iTag[["Sample","Restoration","Depth"]]
map_iTag_only.collumns = ["Sample","Treat","Depth"]


## Drop " (class)", note double esc.
## "Canditatus" genera -> "Cand."
otu_F100["Consensus lineage"] = otu_F100["Consensus lineage"].str.replace(" \(class\)","").str.replace("Candidatus","Cand.")

## Drop chloroplast & mitochondrial reads
otu_F100 = otu_F100[~otu_F100["Consensus lineage"].str.contains("chloroplast")]
otu_F100 = otu_F100[~otu_F100["Consensus lineage"].str.contains("mitochondria")]

## Drop reads with no phylum
otu_F100 = otu_F100[~otu_F100["Consensus lineage"].str.contains("BacteriaKI")]
lineage = otu_F100["Consensus lineage"].str.split(";",expand=True)
lineage = lineage.replace(['k__*','p__*','c__*','o__*','f__*','g__*'],['','','','','',''], regex=True)
lineage.columns = ["Kingdom", "Phylum", "Class", "Order", "Family", "Genus"]

## add split tax into OTU table
otu_F100_LinSp = pd.concat([otu_F100,lineage],1)
otu_F100_LinSp_nophy = otu_F100_LinSp[~otu_F100_LinSp["Phylum"].isnull()]

## fill missing tax using upper level of tax
otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Class"].isnull(),"Class"] = otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Class"].isnull(),"Phylum"] + "PH"
otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Order"].isnull(),"Order"] = otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Order"].isnull(),"Class"] + "CL"
otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Family"].isnull(),"Family"] = otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Family"].isnull(),"Order"] + "OR"
otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Genus"].isnull(),"Genus"] = otu_F100_LinSp_nophy.loc[otu_F100_LinSp_nophy["Genus"].isnull(),"Family"] + "FA"
otu_F100_LinSp_nophy.iloc[:,-6:] = otu_F100_LinSp_nophy.iloc[:,-6:].replace(['PHCLORFA','PHCLOR','PHCL','CLORFA','CLOR','ORFA'],['PH','PH','PH','CL','CL','OR'],regex=True)

## save OTU table
otu_F100_LinSp_nophy.index.name = "#OTU_ID"
otu_F100_LinSp_nophy.iloc[:,:-7].to_csv("OTU_table.txt",sep="\t")

col = otu_F100_LinSp_nophy.columns[:-7]
otu_F100_LinSp_nophy.to_csv("OTU_tax_table.txt",sep="\t")

## save genus table
otu_F100_LinSp_nophy_genus = otu_F100_LinSp_nophy.groupby("Genus")[col].sum()
otu_F100_LinSp_nophy_genus.index.name = "#" + otu_F100_LinSp_nophy_genus.index.name
otu_F100_LinSp_nophy_genus.to_csv("Genus_table.txt",sep="\t")

## save family table
otu_F100_LinSp_nophy_Family = otu_F100_LinSp_nophy.groupby("Family")[col].sum()
otu_F100_LinSp_nophy_Family.index.name = "#" + otu_F100_LinSp_nophy_Family.index.name
otu_F100_LinSp_nophy_Family.to_csv("Family_table.txt",sep="\t")
# Out:
# /Users/jzz0026/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/jzz0026/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
otu_F100_LinSp_nophy_genus
# Out:
#                         R1_A_D1  R1_A_D2  R1_B_D1  R1_B_D2  R1_C_D1  R1_C_D2  \
# #Genus
# 125ds10FA                     0        0        0        0        0        0
# 4C0d-2CL                      0        1        3        0        1        9
# 5bav_B12CL                    0        0        0        0        0        0
# A17                           0        0        0        0        1        0
# A4bOR                         0        0        0        1        0        0
# ABY1_OD1PH                  119      104       29       30       13       15
# AKIW874FA                     1        1        2        0        1        5
# AT425_EubG1CL                 0        0        0        0        0        0
# Acetivibrio                  78       77       92      116       45       52
# AcetobacteraceaeFA            0        0        0        0        0        0
# Acetohalobium                 7        1       67       10       55       64
# AcidimicrobialesOR            8        5       22       19       11       26
# AcidithiobacillaceaeFA        0        0        0        0        0        0
# Acidobacteria-5CL             0        0        0        0        0        0
# AcidobacteriaPH               0        0        0        0        0        0
# AcidobacteriaceaeFA           0        0        1        0        0        2
# AcidobacterialesOR            1        0        0        0        0        0
# Actinoallomurus               0        0        0        0        0        0
# ActinobacteriaCL              0        0        2        0        0        0
# ActinomycetalesOR             1        3       12        7        4       51
# Adhaeribacter                 0        1        0        0        0        0
# Ahrensia                      0        0        0        1        2        2
# AlcaligenaceaeFA             50       62      139       98       75       47
# AlcanivoracaceaeFA          165      120       73       64      136      110
# Alcanivorax                   4        8        4        3        6        2
# Algibacter                    0        1        0        1        0        0
# Algoriphagus                  0        1        0        0        0        2
# Alicyclobacillus              0        0       25        2       11       50
# Alkalilimnicola               0        0        0        0        0        0
# Alkaliphilus                  0        0        3        0        8       53
# ...                         ...      ...      ...      ...      ...      ...
# WM88CL                        3        1        7       16        7      238
# WPS-2PH                       0        1       13        1        1        6
# WS1PH                       118       65       83      117       44      131
# Waddlia                       0        1        0        0        0        1
# Winogradskyella               0        0        0        0        0        0
# XanthomonadaceaeFA            0        1        0        0        0        1
# XanthomonadalesOR             0        0        0        0        0        0
# YS2OR                         0        0        0        0        0        0
# Z20OR                        48       25       29       28      123       17
# ZA3412cFA                     0        0        0        0        1        0
# ZB1OR                         0        0        5        2        1        2
# ZB2PH                        95      154      110      194      107       68
# ZD0117                        2       16        4        5       11        6
# Zobellia                      3        5        0        9        2        9
# Zplanct13                   621      395      478      509      701       94
# envOPS12OR                    0        0        0        0        0        0
# koll11CL                      0        0        6        4        2        4
# koll13OR                      2        2        2        0        2       12
# kpj58rcFA                     0        0        0        0        0        0
# mle1-48OR                     0        0        0        0        0        0
# nsmpVI18                      0        0        0        0        0        0
# ntu14FA                       5        2       16       10       10       16
# pGrfC26OR                     0        0        0        0        0        0
# pMC2A209CL                   77       23      152      176       42       90
# pMC2A33FA                    66       60       48      220      225      302
# so4B24FA                      1        0        0        0        0        0
# vadinHA49CL                   0        0        0        0        0        0
# wb1_H11OR                     0        0        0        0        0        0
# wb1_P06FA                     0        0        0        1        0        0
# za29                          0        0        0        0        0        0
#
#                         R2A_A_D1  R2A_A_D2  R2A_B_D1  R2A_B_D2    ...     \
# #Genus                                                            ...
# 125ds10FA                      0        25        78        22    ...
# 4C0d-2CL                       1         0         1        47    ...
# 5bav_B12CL                     3         1        11       937    ...
# A17                           83      1087       350       221    ...
# A4bOR                       4479      4199      6801      1246    ...
# ABY1_OD1PH                     0         4         2         1    ...
# AKIW874FA                     37        47        11         1    ...
# AT425_EubG1CL                  0         1         1         3    ...
# Acetivibrio                    0         1         0        34    ...
# AcetobacteraceaeFA             0        29         8       361    ...
# Acetohalobium                  0         0         0         0    ...
# AcidimicrobialesOR            20        79        47        65    ...
# AcidithiobacillaceaeFA        63        36         2         0    ...
# Acidobacteria-5CL             25      1059       884       209    ...
# AcidobacteriaPH              201      1238       960      8558    ...
# AcidobacteriaceaeFA            1       487        42      2989    ...
# AcidobacterialesOR            26       725       348       138    ...
# Actinoallomurus                0       146         8       185    ...
# ActinobacteriaCL             502       331       506      2134    ...
# ActinomycetalesOR             29         2        21         6    ...
# Adhaeribacter                 94       142       133         9    ...
# Ahrensia                     844       747       939        71    ...
# AlcaligenaceaeFA               0         0         0         1    ...
# AlcanivoracaceaeFA            18        43         4         1    ...
# Alcanivorax                    0         0         0         0    ...
# Algibacter                   235        69       205        29    ...
# Algoriphagus                 245        78        59        10    ...
# Alicyclobacillus               6       181        49      3350    ...
# Alkalilimnicola              213       344       145        62    ...
# Alkaliphilus                   0         1         3         1    ...
# ...                          ...       ...       ...       ...    ...
# WM88CL                         1         4         4         2    ...
# WPS-2PH                        4         2        12         0    ...
# WS1PH                          0         0         4        59    ...
# Waddlia                       81       183       151        66    ...
# Winogradskyella                6        70         2         5    ...
# XanthomonadaceaeFA             4      3521        55      1773    ...
# XanthomonadalesOR              0        20        11       311    ...
# YS2OR                          0         0         0         1    ...
# Z20OR                          0         0         1         0    ...
# ZA3412cFA                      0       768         8        70    ...
# ZB1OR                         15         2        37       284    ...
# ZB2PH                          1         0         2         0    ...
# ZD0117                        18        92       222        36    ...
# Zobellia                     199       124       314        74    ...
# Zplanct13                      0         1         0         0    ...
# envOPS12OR                   401       179       628       221    ...
# koll11CL                       0         0         0         1    ...
# koll13OR                    1868      2193      2155       691    ...
# kpj58rcFA                      0         3         0         3    ...
# mle1-48OR                     70       132       155        43    ...
# nsmpVI18                       3        61         7         3    ...
# ntu14FA                        0         1         5         0    ...
# pGrfC26OR                      0         0        10       321    ...
# pMC2A209CL                     1         2         0         1    ...
# pMC2A33FA                      0         5         1         0    ...
# so4B24FA                       1         0        12        19    ...
# vadinHA49CL                   32       127        81        19    ...
# wb1_H11OR                     98        58       175        40    ...
# wb1_P06FA                     20        96        96        32    ...
# za29                           0        59         8       475    ...
#
#                         R2_B_D1  R2_B_D2  R2_C_D1  R2_C_D2  SF2_A_D1  \
# #Genus
# 125ds10FA                     0        0        0        0         0
# 4C0d-2CL                     14       73       60       55         0
# 5bav_B12CL                    0        0        0        0        27
# A17                           1        0        0        2         1
# A4bOR                         1        2        0        0        83
# ABY1_OD1PH                   66       17       36       21        62
# AKIW874FA                     4       10        1        1         0
# AT425_EubG1CL                 0        0        0        0        27
# Acetivibrio                  32       90       15       64        25
# AcetobacteraceaeFA            0        1        0        0         0
# Acetohalobium                27       52       19       22         0
# AcidimicrobialesOR           28       94       11       44        26
# AcidithiobacillaceaeFA        0        0        0        0         0
# Acidobacteria-5CL             0        0        0        0         0
# AcidobacteriaPH               0        0        0        0       240
# AcidobacteriaceaeFA           1        2        1        0         0
# AcidobacterialesOR            0        0        0        0         2
# Actinoallomurus               1        1        0        0         0
# ActinobacteriaCL              0        0        0        1        20
# ActinomycetalesOR            62      748        4     1605        51
# Adhaeribacter                55        2      122        1         1
# Ahrensia                      1        2        0        5        26
# AlcaligenaceaeFA             66       36      255      128         0
# AlcanivoracaceaeFA           68       23      116       13         0
# Alcanivorax                  11       13       12        4         0
# Algibacter                    0        1        0        1        14
# Algoriphagus                  0        1        0        0        19
# Alicyclobacillus            427      367        8       25        19
# Alkalilimnicola               1        7        0        1         0
# Alkaliphilus                 13       51        0       11         2
# ...                         ...      ...      ...      ...       ...
# WM88CL                       39      114        4       52       136
# WPS-2PH                      49        3       55       11         0
# WS1PH                       100      163       42      204         1
# Waddlia                       3        2        0        0         0
# Winogradskyella               0        1        0        0         0
# XanthomonadaceaeFA           14       40        0        2         8
# XanthomonadalesOR             1        1        0        1         1
# YS2OR                         0        0        0        0         0
# Z20OR                       128       25      152       38         0
# ZA3412cFA                     0        0        0        0        30
# ZB1OR                        15        4        0        6       471
# ZB2PH                        97      102      120       98         0
# ZD0117                        6        6        2        2        27
# Zobellia                     15      121        0      219        19
# Zplanct13                   218      113      185      110         0
# envOPS12OR                    0        0        0        0       521
# koll11CL                     48       31       65       20         0
# koll13OR                      5        8        0        3       452
# kpj58rcFA                     0        0        0        0        78
# mle1-48OR                     0        0        0        0         0
# nsmpVI18                      0        0        0        0         2
# ntu14FA                      45       75       11       26         5
# pGrfC26OR                     0        0        0        0        40
# pMC2A209CL                   79      170       14       52        64
# pMC2A33FA                   277      131       10       29        17
# so4B24FA                      0        0        0        0       257
# vadinHA49CL                   0        0        0        0        85
# wb1_H11OR                     0        0        0        0       196
# wb1_P06FA                     0        0        0        0        14
# za29                          1        1        1        0         9
#
#                         SF2_A_D2  SF2_B_D1  SF2_B_D2  SF2_C_D1  SF2_C_D2
# #Genus
# 125ds10FA                      0         0         0         0         0
# 4C0d-2CL                      15        10         1         6        84
# 5bav_B12CL                    39        51        52        65        93
# A17                            2         6         3         6         2
# A4bOR                        115       125       128       603        76
# ABY1_OD1PH                    17         0         1        42         0
# AKIW874FA                      3        18        10       118        51
# AT425_EubG1CL                 26       147       142       180        44
# Acetivibrio                  164       744       604       533       755
# AcetobacteraceaeFA             2         0         1         3         3
# Acetohalobium                  0         2         2         6         7
# AcidimicrobialesOR            40        20        23        58        17
# AcidithiobacillaceaeFA         0         0         0         0         0
# Acidobacteria-5CL              1         1         0         1         1
# AcidobacteriaPH              289       280       271       837       213
# AcidobacteriaceaeFA            1         1         1         5         1
# AcidobacterialesOR             2         0         1         3         0
# Actinoallomurus                0         1         0         0         0
# ActinobacteriaCL              79        35        29        56        21
# ActinomycetalesOR            128        33        35       128       110
# Adhaeribacter                  1         1         0         5         0
# Ahrensia                      80        30        27        79        18
# AlcaligenaceaeFA               0         0         2         0         0
# AlcanivoracaceaeFA             1        67        47         9        18
# Alcanivorax                    3       174       132         0       127
# Algibacter                     5        67        78        32         9
# Algoriphagus                  12        16         7        18         2
# Alicyclobacillus             317        75        63       440       524
# Alkalilimnicola                5         9         2         1       107
# Alkaliphilus                   3        15        19        14        37
# ...                          ...       ...       ...       ...       ...
# WM88CL                        78       533       495       195       136
# WPS-2PH                        0         0         0         0         0
# WS1PH                         33        81        67        81       162
# Waddlia                       85        12         4         2        21
# Winogradskyella                0         0         0         0         0
# XanthomonadaceaeFA           143        16        15        30         6
# XanthomonadalesOR              0         0         0         0         0
# YS2OR                         13        21        18        14        52
# Z20OR                          2         4         8         1         5
# ZA3412cFA                     53        39        38        69       170
# ZB1OR                        514       668       604      1305       813
# ZB2PH                          0         0         2         1         0
# ZD0117                        14        16        14        28         4
# Zobellia                      11        10        10        64         5
# Zplanct13                      0         6         1         1         1
# envOPS12OR                   257       289       301       674        45
# koll11CL                       0         0         0         0         1
# koll13OR                     843       132       144       769       115
# kpj58rcFA                     14        44        50        86        13
# mle1-48OR                      1         0         0         1         0
# nsmpVI18                       1         0         0         3         0
# ntu14FA                        3         0         1        10         1
# pGrfC26OR                     82        32        28        79        93
# pMC2A209CL                    30       231       163        94        41
# pMC2A33FA                      9        70        68        88        29
# so4B24FA                     223       259       252      1025       106
# vadinHA49CL                   79        45        57       160        26
# wb1_H11OR                    117        50        66       223        23
# wb1_P06FA                     28        18        18        48         4
# za29                         120        18        30       122       174
#
# [573 rows x 24 columns]
