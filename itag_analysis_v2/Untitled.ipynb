# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
plt.style.use('default')
# !ls ../
# Out:
# 1_Salt_Pond_iTags_16S_sort_python.ipynb
# 2_DEseq_results_analysis.ipynb
# Family_table.biom
# Family_table.txt
# Genus_table.biom
# Genus_table.txt
# OTU_counts_nomalized.csv
# OTU_counts_nomalized_relative.csv
# OTU_difference_res_SH.csv
# OTU_difference_res_SR.csv
# OTU_difference_summary.csv
# OTU_table.biom
# OTU_table.txt
# OTU_table_DES_QI.biom
# OTU_table_DES_QI.txt
# OTU_tax_table.txt
# R-DESeq_analysis.ipynb
# R-edger_analysis.ipynb
# README.md
# Salt_Pond_iTags_16S_Deseq2-JZ.ipynb
# Salt_pond_16S_otu.tax.filtered.txt
# Salt_pond_ALL_Meta_whh.txt
# Saltpond_vs_NoSaltpond
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# diff_OTU_table_HS.txt
# diff_OTU_table_HS_diagnostic_plots.pdf
# diff_family_table_HS.txt
# diff_family_table_HS_diagnostic_plots.pdf
# diff_genus_table_HS.txt
# diff_genus_table_HS_diagnostic_plots.pdf
# family_test.txt
# map.txt
# old
# sourcetrack
# wrap.edgeR.r

# %%
Res2_rel = pd.read_csv("OTU_counts_nomalized.csv",index_col=0)
Res1_rel = pd.read_csv("../OTU_counts_nomalized.csv",index_col=0)
qiime = pd.read_csv("../OTU_table_DES_QI.txt",sep="\t",header=1,index_col=0)
#qiime = 2 ** qiime
#qiime = (qiime / qiime.sum()) * 1000000
qiime = qiime.loc[:,Res1_rel.columns]
qiime.head()
# Out:
#          R2A_A_D1  R2A_A_D2  R2A_B_D1  R2A_B_D2  R2A_C_D1  R2A_C_D2  SF2_A_D1  \
# #OTU ID
# 0          3.2132   5.82800   5.35430    1.9849  5.007700   0.46072   0.82299
# 1          8.8425   7.78360   8.01660    5.6261  7.197100   2.98570   5.19930
# 2         -1.7982   0.13215  -0.91847   -1.1757  0.040263  -1.35710  -2.01730
# 3         11.3300   8.13110   8.68130    3.4304  5.719300   2.12670   6.07470
# 4          1.7323   6.25830   6.81480    3.6870  5.719300   2.98570   0.82299
#
#          SF2_A_D2  SF2_B_D1  SF2_B_D2   ...     R1_B_D1  R1_B_D2  R1_C_D1  \
# #OTU ID                                 ...
# 0         0.89801    4.0929    3.7195   ...     14.4370  15.3150   15.386
# 1         5.31420    5.6058    5.5982   ...     14.5460  14.5200   14.080
# 2        -0.90864   -1.8574   -1.7026   ...      1.3282   2.9529    4.085
# 3         4.09750    4.0929    4.5786   ...     14.1620  14.1020   14.711
# 4         3.32890    3.6942    4.0599   ...     14.2180  14.2990   14.594
# ...

# %%
Res1_rel
# Out:
#          R2A_A_D1     R2A_A_D2     R2A_B_D1     R2A_B_D2      R2A_C_D1  \
# 0        4.105168    39.394831    23.693098    20.938574     42.681015
# 1      143.680867   140.344085   130.970182   164.018827    170.724060
# 2        0.000000     1.231088     0.658142     3.489762      2.134051
# 3      806.958666   177.276738   205.340185    45.366910     66.155573
# 4        1.759358    51.705715    59.232746    52.346434     66.155573
# 5     2069.004488  1091.975465  1157.671108  2449.813116    548.451044
# 6       14.074860    27.083946    15.795399    20.938574     10.670254
# 7      137.229889    41.857008    81.609561    62.815721     46.949117
# 8        7.623883     8.617619    11.188408    83.754295     10.670254
# 9        1.759358     3.693265     0.000000     3.489762      0.000000
# 10     377.675422    11.079796    23.034957     6.979525      4.268102
# 11       1.759358    29.546123     3.948850    24.428336      4.268102
# ...

# %%
Res2_rel.head()
# Out:
#      R2A_A_D1    R2A_A_D2    R2A_B_D1    R2A_B_D2    R2A_C_D1   R2A_C_D2  \
# 0    4.105168   39.394831   23.693098   20.938574   42.681015   9.045736
# 1  143.680867  140.344085  130.970182  164.018827  170.724060  45.228678
# 2    0.000000    1.231088    0.658142    3.489762    2.134051   0.000000
# 3  806.958666  177.276738  205.340185   45.366910   66.155573  27.137207
# 4    1.759358   51.705715   59.232746   52.346434   66.155573  45.228678
#
#      SF2_A_D1   SF2_A_D2   SF2_B_D1   SF2_B_D2     ...           R1_B_D1  \
# 0    5.986653   4.147815  21.427786  20.877701     ...       7301.471672
# 1   74.833160  48.391180  52.283797  62.633102     ...       7873.910303
# 2    0.000000   1.382605   0.857111   1.098826     ...          1.354884
# 3  128.713036  23.504288  21.427786  34.063617     ...       6036.009705
# 4    5.986653  15.208657  17.142229  25.273006     ...       6278.534000
#
#         R1_B_D2       R1_C_D1       R1_C_D2       R2_A_D1      R2_A_D2  \
# ...

# %%
dft = pd.read_csv("../OTU_table.txt",sep="\t",index_col=0)
#dft = dft / dft.sum() * 1000000
dft = dft.loc[:,Res1_rel.columns]
dft.head()
# Out:
#          R2A_A_D1  R2A_A_D2  R2A_B_D1  R2A_B_D2  R2A_C_D1  R2A_C_D2  SF2_A_D1  \
# #OTU_ID
# 0               7        32        36         6        20         1         2
# 1             245       114       199        47        80         5        25
# 2               0         1         1         1         1         0         0
# 3            1376       144       312        13        31         3        43
# 4               3        42        90        15        31         5         2
#
#          SF2_A_D2  SF2_B_D1  SF2_B_D2   ...     R1_B_D1  R1_B_D2  R1_C_D1  \
# #OTU_ID                                 ...
# 0               3        25        19   ...       10778    18826    20138
# 1              35        61        57   ...       11623    10951     8231
# 2               1         1         1   ...           2        5       10
# 3              17        25        31   ...        8910     8200    12724
# 4              11        20        23   ...        9268     9397    11739
# ...

# %%
dftt = pd.read_csv("../Salt_pond_16S_otu.tax.filtered.txt",sep="\t",index_col=0)
#dftt = dftt / dftt.sum() * 1000000
dftt = dftt.loc[:,Res1_rel.columns]
#dftt = dftt / dftt.sum() * 1000000
dftt
# Out:
#         R2A_A_D1  R2A_A_D2  R2A_B_D1  R2A_B_D2  R2A_C_D1  R2A_C_D2  SF2_A_D1  \
# OTU_ID
# 0              7        32        36         6        20         1         2
# 1            245       114       199        47        80         5        25
# 2              0         1         1         1         1         0         0
# 3           1376       144       312        13        31         3        43
# 4              3        42        90        15        31         5         2
# 5           3528       887      1759       702       257        21     14222
# 6             24        22        24         6         5         3         0
# 7            234        34       124        18        22         9        22
# 8             13         7        17        24         5         1        32
# 9              3         3         0         1         0         0         0
# 10           644         9        35         2         2         5         6
# ...

# %%
dft = pd.read_csv("/Users/jzz0026/Downloads/otu/FAPROTAX/otu_table_tax.faprotax.txt",sep="\t",index_col=0)
dft.iloc[:,1:].sum()
# Out:
# R1_A_D1                153244
# R1_A_D2                134454
# R1_B_D1                134001
# R1_B_D2                100010
# R1_B_H2O                79206
# R1_C_D1                125566
# R1_C_D2                133096
# R2A_A_D1                94677
# R2A_A_D2                80536
# R2A_B_D1                88834
# R2A_B_D2               116096
# R2A_C_D1                85855
# R2A_C_D2               118977
# R2_A_D1                122365
# R2_A_D2                129387
# R2_A_H2O               113357
# R2_B_D1                156293
# R2_B_D2                 89754
# R2_B_H2O                49323
# R2_C_D1                208567
# R2_C_D2                121960
# R2_C_H2O                20286
# R2_restored_C_black    187330
# R2_restored_D_shore    103179
# SF2_A_D1               107066
# SF2_A_D2               118070
# SF2_B_D1               107750
# SF2_B_D2                99079
# SF2_C_D1               220010
# SF2_C_D2                92912
# dtype: int64
