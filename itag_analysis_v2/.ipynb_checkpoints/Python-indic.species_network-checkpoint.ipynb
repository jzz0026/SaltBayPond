# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.stats.multitest as smt
# %matplotlib inline

# %% [markdown]
# ## read normalized OTU table

# %%
OTU_counts_nomalized = pd.read_csv("OTU_counts_nomalized.csv",index_col=0)
OTU_counts_nomalized_relative_tax = pd.read_csv("OTU_counts_nomalized_relative_tax.csv",index_col=0)
OTU_tax = OTU_counts_nomalized_relative_tax.iloc[:,-7:]

OTU_counts_nomalized_tax = pd.merge(OTU_counts_nomalized,OTU_tax,left_index=True,right_index=True,how="left")

Sample_col = OTU_counts_nomalized.columns

# %% [markdown]
# ## read indic.species results

# %%
indic_species = pd.read_csv("indic_species_result.csv",index_col=0)
len(indic_species)

indic_species_p001 = indic_species[indic_species["p.value"] < 0.001]
indic_species_p001 = indic_species_p001[indic_species_p001["stat"] > 0.5]

Historic_uniq = indic_species_p001[indic_species_p001["index"] == 1]
Restored_uniq = indic_species_p001[indic_species_p001["index"] == 2]
Saltpond_uniq = indic_species_p001[indic_species_p001["index"] == 3]

group_OTU_SP = OTU_counts_nomalized_tax.loc[Saltpond_uniq.index].groupby("Family")[Sample_col].sum()
group_OTU_RS = OTU_counts_nomalized_tax.loc[Restored_uniq.index].groupby("Family")[Sample_col].sum()
group_OTU_HI = OTU_counts_nomalized_tax.loc[Historic_uniq.index].groupby("Family")[Sample_col].sum()

mean_SP_unique = group_OTU_SP.iloc[:,-12:].sum(1).sort_values(ascending=False)/12
mean_RS_unique = group_OTU_RS.iloc[:,6:-12].sum(1).sort_values(ascending=False)/6
mean_HI_unique = group_OTU_HI.iloc[:,:6].sum(1).sort_values(ascending=False)/6

# %%
Historic_Restored_uniq = indic_species_p001[indic_species_p001["index"] == 4]
group_OTU_HI_RS = OTU_counts_nomalized_tax.loc[Historic_Restored_uniq.index].groupby("Family")[Sample_col].sum()
HI_RS_col = [a for a in group_OTU_HI_RS.columns if "R2A" in a or "SF2" in a]
mean_HI_RS_unique = group_OTU_HI_RS.loc[:,HI_RS_col].sum(1).sort_values(ascending=False)/len(HI_RS_col)
mean_HI_RS_unique
# Out:
# Family
# Rhodobacteraceae      1229.735983
# GCA004OR               105.077721
# SphingomonadalesOR      17.317281
# dtype: float64

# %%
Historic_SaltPond_uniq = indic_species_p001[indic_species_p001["index"] == 5]
group_OTU_HI_SP = OTU_counts_nomalized_tax.loc[Historic_SaltPond_uniq.index].groupby("Family")[Sample_col].sum()
HI_SP_col = [a for a in group_OTU_HI_SP.columns if "R2A" in a or "R1_" in a or "R2_" in a]
mean_HI_SP_unique = group_OTU_HI_SP.loc[:,HI_SP_col].sum(1).sort_values(ascending=False)/len(HI_SP_col)
mean_HI_SP_unique
# Out:
# Family
# Rhodobacteraceae    34.309663
# dtype: float64

# %% [markdown]
# ## Plot network

# %%
import networkx as nx

plt.figure(figsize=(10,10))

## select top 20 of meanbase
t1 = mean_SP_unique.nlargest(10)
t2 = mean_RS_unique.nlargest(10)
t3 = mean_HI_unique.nlargest(10)

t4 = mean_HI_RS_unique
t5 = mean_HI_SP_unique

## add to type
edges_t1 = [["Salt_pond",a+"_1"] for a in t1.index]
edges_t2 = [["Restored",a+"_2"] for a in t2.index]
edges_t3 = [["Historic",a+"_3"] for a in t3.index]

edges_t4 = [["Historic",a+"_4"] for a in t4.index] + [["Restored",a+"_4"] for a in t4.index]
edges_t5 = [["Historic",a+"_5"] for a in t5.index] + [["Salt_pond",a+"_5"] for a in t5.index]

## transform basemean to size
size1=[2500]+[a/10 for a in list(t1)]
size2=[2500]+[a/10 for a in list(t2)]
size3=[2500]+[a/10 for a in list(t3)]

size4=[a/10 for a in list(t4)]
size5=[a/10 for a in list(t5)]

edges = edges_t1+edges_t2+edges_t3+edges_t4+edges_t5+[["Salt_pond","Restored"]]

## Color Palette
dfcolor = pd.DataFrame(edges)
dfcolor[2] = [a[0] for a in dfcolor[1].str.split("_")]
family_uni = dfcolor[2].unique()[:-1]

xx = OTU_tax[["Phylum","Class","Order","Family"]].sort_values("Family")
xx = xx.groupby(["Phylum","Class","Order","Family"]).size().reset_index(name='Freq')

color_xx = pd.merge(pd.DataFrame(family_uni),xx,left_on=0,right_on="Family",how="left")
color_xx = color_xx.sort_values("Phylum")
uni_phylum = color_xx["Phylum"].unique()

colors =['#E41A1C','#4A72A6','#84f8ff','#3E8E93','#48A462','#5D995D','#974661','#A35390','#2a5800','#cad15e','#7E6E85','#D16948','#FF7F00','#FFB716','#FFF02D','#fff0bd','#E1C62F','#B97B2A','#B75F49','#ffa5a9','#DB728C','#EC83BA','#C28EA9','#d5aaaa','#f2c6f2','#f8f0f0','#d1d1d1','#999999']

color_xx["color"] = colors
color = color_xx[[0,'color']]
dfcolor2 = pd.merge(dfcolor,color,left_on=2,right_on=0,how="left")

color_final = list(dfcolor2['color'])
color_final = ["#ffffff"]+color_final[:10]+["#ffffff"]+color_final[10:20]+["#ffffff"]+color_final[20:33]+color_final[36:37]


## plot network
g = nx.Graph(edges)
#pos = nx.circular_layout(g)

## set dictionary to change node labels 
mapping = list(g.nodes())
mapping_t = mapping.copy()
mapping_t[1:11] = np.arange(1,11)
mapping_t[12:22] = np.arange(1,11)
mapping_t[23:33] = np.arange(1,11)
mapping_t[33:] = ['','','']
mapping2 = dict(zip(mapping,mapping_t))


## add size, line color, node color, change node labels
nx.draw_networkx(g,node_size=size1+size2+size3+size4+size5,edge_color='grey',node_color=color_final,width=1.5,labels=mapping2)


## set outline of node
ax = plt.gca() # to get the current axis
ax.collections[0].set_edgecolor("#000000") 

plt.axis('off') ## remove axis

## set legend
a_leng = list(color_xx[0])
b_leng = list(color_xx["color"])
legend_elements=[]

for a,b in zip(a_leng,b_leng):
    legend_elements.append(Line2D([0], [0], marker='o', color="white", label=a,markerfacecolor=b, markersize=15))

legend = plt.legend(handles=legend_elements, loc='best', bbox_to_anchor=(1, 0.5, 0.2, 0.5), prop={'size': 12}, title="Family")
plt.setp(legend.get_title(),fontsize='xx-large')
# Out:
# [None, None]

# %%
#mean_SP_unique
#mean_RS_unique
mean_HI_unique
# Out:
# Family
# AcidobacteriaPH          9933.657956
# GemmatimonadetesCL       8989.901924
# Rhodospirillaceae        8437.366544
# Hyphomicrobiaceae        7364.678850
# Rhodothermaceae          6001.967756
# Xanthomonadaceae         5779.986619
# Flavobacteriaceae        5073.085962
# GammaproteobacteriaCL    4974.816178
# A4bOR                    3789.257819
# Saprospiraceae           3349.627645
# Acidobacteriaceae        3185.815163
# PirellulalesOR           3138.084538
# Sinobacteraceae          3052.027035
# RhizobialesOR            2576.209025
# koll13OR                 2565.493157
# Solibacteraceae          2561.192234
# EC214CL                  2454.762922
# Phyllobacteriaceae       2382.855724
# Flammeovirgaceae         2325.536238
# ChromatialesOR           2303.518914
# GN03OR                   1969.328158
# Cenarchaeaceae           1960.917272
# Syntrophobacteraceae     1860.912127
# SphingobacterialesOR     1797.834852
# AnaerolineaeCL           1702.793050
# Marinilabiaceae          1469.312916
# Planctomycetaceae        1404.863012
# Ignavibacteriaceae       1397.223482
# JTB38                    1381.426365
# CaldithrixalesOR         1322.514554
#                             ...
# KueneniaeCL                83.578938
# PhycisphaeraeCL            83.167159
# BurkholderialesOR          82.360320
# GemmatimonadalesOR         80.118120
# C6CL                       73.030844
# HN1-15OR                   66.846546
# Erythrobacteraceae         58.972854
# Bacillaceae                55.078125
# vadinHA49CL                51.790403
# 125ds10                    46.213147
# KSB1PH                     45.270442
# Microthrixaceae            44.623205
# BacteroidalesOR            44.338462
# CH21CL                     43.000895
# Rhabdochlamydiaceae        42.017332
# Cohaesibacteraceae         37.886274
# Spartobacteriaceae         34.065841
# PRR-12CL                   33.929063
# HTCC2188                   31.355686
# AlteromonadalesOR          30.899306
# Hyphomonadaceae            30.495181
# NKB15OR                    29.540620
# Legionellaceae             29.516036
# Deinococcaceae             27.122435
# Chromatiaceae              24.718556
# Moraxellaceae              22.789447
# NautilialesOR              22.148834
# DesulfobacteralesOR        21.538762
# Patulibacteraceae          18.156005
# ChloroflexiPH              13.712695
# Length: 152, dtype: float64

# %%
#len(set([a[1].split("_")[0] for a in edges]))
dfcolor = pd.DataFrame(edges)
dfcolor[2] = [a[0] for a in dfcolor[1].str.split("_")]
family_uni = dfcolor[2].unique()[:-1]
len(family_uni)
#family_uni
# Out:
# 28

# %%
xx = OTU_tax[["Phylum","Class","Order","Family"]].sort_values("Family")
xx = xx.groupby(["Phylum","Class","Order","Family"]).size().reset_index(name='Freq')

color_xx = pd.merge(pd.DataFrame(family_uni),xx,left_on=0,right_on="Family",how="left")
color_xx = color_xx.sort_values("Phylum")
uni_phylum = color_xx["Phylum"].unique()
len(uni_phylum)
# Out:
# 7

# %%
color_xx#.groupby("Phylum").size()
# Out:
#                         0            Phylum                  Class  \
# 17        AcidobacteriaPH     Acidobacteria        AcidobacteriaPH
# 25         Saprospiraceae     Bacteroidetes        Sphingobacteria
# 2            Balneolaceae     Bacteroidetes        Sphingobacteria
# 23      Flavobacteriaceae     Bacteroidetes          Flavobacteria
# 7         BacteroidalesOR     Bacteroidetes            Bacteroidia
# 21        Rhodothermaceae     Bacteroidetes        Sphingobacteria
# 24                  A4bOR       Chloroflexi           Anaerolineae
# 26               GCA004OR       Chloroflexi           Anaerolineae
# 5         ClostridialesOR        Firmicutes             Clostridia
# 6        Halanaerobiaceae        Firmicutes             Clostridia
# 18     GemmatimonadetesCL  Gemmatimonadetes       Gemmatimonadetes
# 0        Rhodobacteraceae    Proteobacteria    Alphaproteobacteria
# 22       Xanthomonadaceae    Proteobacteria    Gammaproteobacteria
# 20      Hyphomicrobiaceae    Proteobacteria    Alphaproteobacteria
# 19      Rhodospirillaceae    Proteobacteria    Alphaproteobacteria
# 16                   OM60    Proteobacteria    Gammaproteobacteria
# 13         ChromatialesOR    Proteobacteria    Gammaproteobacteria
# 14    CampylobacteralesOR    Proteobacteria  Epsilonproteobacteria
# 12       Desulfobulbaceae    Proteobacteria    Deltaproteobacteria
# 11     Desulfobacteraceae    Proteobacteria    Deltaproteobacteria
# 10   DesulfuromonadalesOR    Proteobacteria    Deltaproteobacteria
# 9         Sinobacteraceae    Proteobacteria    Gammaproteobacteria
# 8      Desulfohalobiaceae    Proteobacteria    Deltaproteobacteria
# 3   GammaproteobacteriaCL    Proteobacteria    Gammaproteobacteria
# 1        Alteromonadaceae    Proteobacteria    Gammaproteobacteria
# 15   Syntrophobacteraceae    Proteobacteria    Deltaproteobacteria
# 27     SphingomonadalesOR    Proteobacteria    Alphaproteobacteria
# 4         Spirochaetaceae      Spirochaetes           Spirochaetes
#
#                     Order                 Family  Freq    color
# 17        AcidobacteriaPH        AcidobacteriaPH    18  #E41A1C
# 25     Sphingobacteriales         Saprospiraceae    65  #4A72A6
# 2      Sphingobacteriales           Balneolaceae    30  #84f8ff
# 23       Flavobacteriales      Flavobacteriaceae    71  #3E8E93
# 7           Bacteroidales        BacteroidalesOR   162  #48A462
# 21     Sphingobacteriales        Rhodothermaceae    33  #5D995D
# 24                    A4b                  A4bOR    50  #974661
# 26                 GCA004               GCA004OR    29  #A35390
# 5           Clostridiales        ClostridialesOR    33  #2a5800
# 6         Halanaerobiales       Halanaerobiaceae    28  #cad15e
# 18     GemmatimonadetesCL     GemmatimonadetesCL    67  #7E6E85
# 0         Rhodobacterales       Rhodobacteraceae    85  #D16948
# 22        Xanthomonadales       Xanthomonadaceae     6  #FF7F00
# 20            Rhizobiales      Hyphomicrobiaceae    15  #FFB716
# 19       Rhodospirillales      Rhodospirillaceae    93  #FFF02D
# 16      Oceanospirillales                   OM60    20  #fff0bd
# 13           Chromatiales         ChromatialesOR    86  #E1C62F
# 14      Campylobacterales    CampylobacteralesOR     4  #B97B2A
# 12      Desulfobacterales       Desulfobulbaceae    81  #B75F49
# 11    Syntrophobacterales     Desulfobacteraceae   144  #ffa5a9
# 10     Desulfuromonadales   DesulfuromonadalesOR    15  #DB728C
# 9         Xanthomonadales        Sinobacteraceae    44  #EC83BA
# 8      Desulfovibrionales     Desulfohalobiaceae    17  #C28EA9
# 3   GammaproteobacteriaCL  GammaproteobacteriaCL    72  #d5aaaa
# 1         Alteromonadales       Alteromonadaceae    18  #f2c6f2
# 15    Syntrophobacterales   Syntrophobacteraceae    35  #f8f0f0
# 27       Sphingomonadales     SphingomonadalesOR     8  #d1d1d1
# 4          Spirochaetales        Spirochaetaceae    95  #999999

# %%
colors =['#E41A1C','#4A72A6','#84f8ff','#3E8E93','#48A462','#5D995D','#974661','#A35390','#2a5800','#cad15e','#7E6E85','#D16948','#FF7F00','#FFB716','#FFF02D','#fff0bd','#E1C62F','#B97B2A','#B75F49','#ffa5a9','#DB728C','#EC83BA','#C28EA9','#d5aaaa','#f2c6f2','#f8f0f0','#d1d1d1','#999999']

sns.palplot(colors)
sns.palplot(['#e8ebea'])
len(colors)
# Out:
# 28

# %%
color_xx["color"] = colors
color = color_xx[[0,'color']]
dfcolor2 = pd.merge(dfcolor,color,left_on=2,right_on=0,how="left")
dfcolor2
# Out:
#           0_x                        1                      2  \
# 0   Salt_pond       Rhodobacteraceae_1       Rhodobacteraceae
# 1   Salt_pond       Alteromonadaceae_1       Alteromonadaceae
# 2   Salt_pond           Balneolaceae_1           Balneolaceae
# 3   Salt_pond  GammaproteobacteriaCL_1  GammaproteobacteriaCL
# 4   Salt_pond        Spirochaetaceae_1        Spirochaetaceae
# 5   Salt_pond        ClostridialesOR_1        ClostridialesOR
# 6   Salt_pond       Halanaerobiaceae_1       Halanaerobiaceae
# 7   Salt_pond        BacteroidalesOR_1        BacteroidalesOR
# 8   Salt_pond     Desulfohalobiaceae_1     Desulfohalobiaceae
# 9   Salt_pond        Sinobacteraceae_1        Sinobacteraceae
# 10   Restored   DesulfuromonadalesOR_2   DesulfuromonadalesOR
# 11   Restored     Desulfobacteraceae_2     Desulfobacteraceae
# 12   Restored        Sinobacteraceae_2        Sinobacteraceae
# 13   Restored       Desulfobulbaceae_2       Desulfobulbaceae
# 14   Restored         ChromatialesOR_2         ChromatialesOR
# 15   Restored    CampylobacteralesOR_2    CampylobacteralesOR
# 16   Restored  GammaproteobacteriaCL_2  GammaproteobacteriaCL
# 17   Restored        BacteroidalesOR_2        BacteroidalesOR
# 18   Restored   Syntrophobacteraceae_2   Syntrophobacteraceae
# 19   Restored                   OM60_2                   OM60
# 20   Historic        AcidobacteriaPH_3        AcidobacteriaPH
# 21   Historic     GemmatimonadetesCL_3     GemmatimonadetesCL
# 22   Historic      Rhodospirillaceae_3      Rhodospirillaceae
# 23   Historic      Hyphomicrobiaceae_3      Hyphomicrobiaceae
# 24   Historic        Rhodothermaceae_3        Rhodothermaceae
# 25   Historic       Xanthomonadaceae_3       Xanthomonadaceae
# 26   Historic      Flavobacteriaceae_3      Flavobacteriaceae
# 27   Historic  GammaproteobacteriaCL_3  GammaproteobacteriaCL
# 28   Historic                  A4bOR_3                  A4bOR
# 29   Historic         Saprospiraceae_3         Saprospiraceae
# 30   Historic       Rhodobacteraceae_4       Rhodobacteraceae
# 31   Historic               GCA004OR_4               GCA004OR
# 32   Historic     SphingomonadalesOR_4     SphingomonadalesOR
# 33   Restored       Rhodobacteraceae_4       Rhodobacteraceae
# 34   Restored               GCA004OR_4               GCA004OR
# 35   Restored     SphingomonadalesOR_4     SphingomonadalesOR
# 36   Historic       Rhodobacteraceae_5       Rhodobacteraceae
# 37  Salt_pond       Rhodobacteraceae_5       Rhodobacteraceae
# 38  Salt_pond                 Restored               Restored
#
#                       0_y    color
# 0        Rhodobacteraceae  #D16948
# 1        Alteromonadaceae  #f2c6f2
# 2            Balneolaceae  #84f8ff
# 3   GammaproteobacteriaCL  #d5aaaa
# 4         Spirochaetaceae  #999999
# 5         ClostridialesOR  #2a5800
# 6        Halanaerobiaceae  #cad15e
# 7         BacteroidalesOR  #48A462
# 8      Desulfohalobiaceae  #C28EA9
# 9         Sinobacteraceae  #EC83BA
# 10   DesulfuromonadalesOR  #DB728C
# 11     Desulfobacteraceae  #ffa5a9
# 12        Sinobacteraceae  #EC83BA
# 13       Desulfobulbaceae  #B75F49
# 14         ChromatialesOR  #E1C62F
# 15    CampylobacteralesOR  #B97B2A
# 16  GammaproteobacteriaCL  #d5aaaa
# 17        BacteroidalesOR  #48A462
# 18   Syntrophobacteraceae  #f8f0f0
# 19                   OM60  #fff0bd
# 20        AcidobacteriaPH  #E41A1C
# 21     GemmatimonadetesCL  #7E6E85
# 22      Rhodospirillaceae  #FFF02D
# 23      Hyphomicrobiaceae  #FFB716
# 24        Rhodothermaceae  #5D995D
# 25       Xanthomonadaceae  #FF7F00
# 26      Flavobacteriaceae  #3E8E93
# 27  GammaproteobacteriaCL  #d5aaaa
# 28                  A4bOR  #974661
# 29         Saprospiraceae  #4A72A6
# 30       Rhodobacteraceae  #D16948
# 31               GCA004OR  #A35390
# 32     SphingomonadalesOR  #d1d1d1
# 33       Rhodobacteraceae  #D16948
# 34               GCA004OR  #A35390
# 35     SphingomonadalesOR  #d1d1d1
# 36       Rhodobacteraceae  #D16948
# 37       Rhodobacteraceae  #D16948
# 38                    NaN      NaN

# %%
color_final = list(dfcolor2['color'])
color_final = ["#ffffff"]+color_final[:10]+["#ffffff"]+color_final[10:20]+["#ffffff"]+color_final[20:33]+color_final[36:37]
color_final
# Out:
# ['#ffffff',
#  '#D16948',
#  '#f2c6f2',
#  '#84f8ff',
#  '#d5aaaa',
#  '#999999',
#  '#2a5800',
#  '#cad15e',
#  '#48A462',
#  '#C28EA9',
#  '#EC83BA',
#  '#ffffff',
#  '#DB728C',
#  '#ffa5a9',
#  '#EC83BA',
#  '#B75F49',
#  '#E1C62F',
#  '#B97B2A',
#  '#d5aaaa',
#  '#48A462',
#  '#f8f0f0',
#  '#fff0bd',
#  '#ffffff',
#  '#E41A1C',
#  '#7E6E85',
#  '#FFF02D',
#  '#FFB716',
#  '#5D995D',
#  '#FF7F00',
#  '#3E8E93',
#  '#d5aaaa',
#  '#974661',
#  '#4A72A6',
#  '#D16948',
#  '#A35390',
#  '#d1d1d1',
#  '#D16948']
